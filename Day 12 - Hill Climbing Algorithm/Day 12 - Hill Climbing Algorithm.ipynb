# %% [markdown]
# # Day 12 - Hill Climbing Algorithm

# %% [markdown]
# ## Part 1

# %%
with open('input_day12.txt') as f_in:
    data = f_in.read()
lines = data.split('\n')[:-1]

with open('test_day12.txt') as f_in:
    data = f_in.read()
test_lines = data.split('\n')

#lines = test_lines

"""
A* algorithm:

~ initialize algorithm: 

- create a TO_BE_VISITED list (containing only the start node)
- set the distance of start (from start) node as zero. All other nodes at dist = inf
- set the TOTAL estimated distance of start node = heuristic distance (all other distances = inf)

~ Algorithm loop:

while TO_BE_VISITED is not empty:
    - update current node to a node in TO_BE_VISITED with the minimum distance to end (distance from 
    start + heuristic)
    - check if current node is the end node (if so terminate the algorithm)
    - check for connected nodes and add all connected nodes to the TO_BE_VISITED list and calculate:
        a) min distance from start node (update if current path is better)
        b) heuristic distance from the end position
    - set current node as visited
"""

row_num = len(lines)
col_num = len(lines[0])

f_scores = {} #estimated distance to end (f_score = g_score + heuristic)
g_scores = {} #distance from start

start = None
end = None

openSet = [] #unvisited
closedSet = [] #visited

def checkHeight(pos_tuple):
    if lines[pos_tuple[0]][pos_tuple[1]] == 'E':
        return 26
    else:
        return ord(lines[pos_tuple[0]][pos_tuple[1]])-96

def heuristic(start_tuple,end_tuple):
    return abs(start_tuple[0]-end_tuple[0]) + abs(start_tuple[1]-end_tuple[1])

for row_idx in range(row_num):
    for col_idx in range(col_num):
        if lines[row_idx][col_idx] == 'S':
            start = (row_idx,col_idx)
            g_scores[(row_idx,col_idx)] = 0
        elif lines[row_idx][col_idx] == 'E':
            end = (row_idx,col_idx)
            g_scores[end] = float('inf')
            f_scores[end] = float('inf')
        else:
            g_scores[(row_idx,col_idx)] = float('inf')
            f_scores[(row_idx,col_idx)] = float('inf')
            
f_scores[start] = heuristic(start,end)
openSet.append(start)
counter = 0
print(f'start = {start}')
print(f'end = {end}')

while openSet != [] and counter<10000:
    
    counter += 1
    current = None
    best_f_score = float('inf')
    
    for node in openSet:
        if f_scores[node]<best_f_score:
            best_f_score = f_scores[node]
            current = node
    
    if current == None:
        print('SOMETHING WENT WRONG')
        break
        
    if current == end:
        print('found end')
        print(f'min distance = {f_scores[current]}')
        break
    
    print(f'currently looking at node = {current}')
    
    openSet.remove(current)
    #check connected nodes 
    
    possible_neighbours = []
    
    if current[0]>0:
        #above
        possible_neighbours.append((current[0]-1,current[1]))
        
    if current[0]<row_num-1:
        #below
        possible_neighbours.append((current[0]+1,current[1]))
        
    if current[1]>0:
        #left
        possible_neighbours.append((current[0],current[1]-1))
        
    if current[1]<col_num-1:
        #right
        possible_neighbours.append((current[0],current[1]+1))
    
    #print(possible_neighbours)

    if current == start:
        current_height = 1
    else:
        current_height = checkHeight(current)
    
    neighbours_to_update = []
    
    for neighbour in possible_neighbours:
        if checkHeight(neighbour)-current_height <= 1:
            neighbours_to_update.append(neighbour)
    
    #print(neighbours_to_update)
    
    for neighbour in neighbours_to_update:
        #print(f'checking neighbour: {neighbour}')
        if neighbour in closedSet:
            #print(f'neighbour: {neighbour} already been looked at... moving on')
            continue
        if neighbour not in openSet:
            openSet.append(neighbour)
        new_g_score = g_scores[current] + 1
        
        if new_g_score < g_scores[neighbour]:
            g_scores[neighbour] = new_g_score
            f_scores[neighbour] = new_g_score + heuristic(neighbour,end)
        #print(f'g_scores and f_scores for {neighbour} = {g_scores[neighbour]}, {f_scores[neighbour]}')
            
    closedSet.append(current)
# Out:
# start = (20, 0)
# end = (20, 112)
# currently looking at node = (20, 0)
# currently looking at node = (20, 1)
# currently looking at node = (20, 2)
# currently looking at node = (20, 3)
# currently looking at node = (20, 4)
# currently looking at node = (20, 5)
# currently looking at node = (20, 6)
# currently looking at node = (19, 0)
# currently looking at node = (21, 0)
# currently looking at node = (19, 1)
# currently looking at node = (21, 1)
# currently looking at node = (19, 2)
# currently looking at node = (21, 2)
# currently looking at node = (19, 3)
# currently looking at node = (21, 3)
# currently looking at node = (19, 4)
# currently looking at node = (21, 4)
# currently looking at node = (19, 5)
# currently looking at node = (21, 5)
# currently looking at node = (19, 6)
# currently looking at node = (21, 6)
# currently looking at node = (19, 7)
# currently looking at node = (19, 8)
# currently looking at node = (19, 9)
# currently looking at node = (19, 10)
# currently looking at node = (20, 10)
# currently looking at node = (19, 11)
# currently looking at node = (18, 0)
# currently looking at node = (22, 0)
# currently looking at node = (18, 1)
# currently looking at node = (22, 1)
# currently looking at node = (18, 2)
# currently looking at node = (22, 2)
# currently looking at node = (18, 3)
# currently looking at node = (22, 3)
# currently looking at node = (18, 4)
# currently looking at node = (18, 5)
# currently looking at node = (18, 6)
# currently looking at node = (18, 7)
# currently looking at node = (18, 8)
# currently looking at node = (18, 9)
# currently looking at node = (18, 10)
# currently looking at node = (22, 4)
# currently looking at node = (22, 5)
# currently looking at node = (22, 6)
# currently looking at node = (22, 7)
# currently looking at node = (21, 7)
# currently looking at node = (22, 8)
# currently looking at node = (20, 7)
# currently looking at node = (21, 8)
# currently looking at node = (22, 9)
# currently looking at node = (20, 8)
# currently looking at node = (21, 9)
# currently looking at node = (22, 10)
# currently looking at node = (20, 9)
# currently looking at node = (21, 10)
# currently looking at node = (22, 11)
# currently looking at node = (21, 11)
# currently looking at node = (22, 12)
# currently looking at node = (20, 11)
# currently looking at node = (21, 12)
# currently looking at node = (22, 13)
# currently looking at node = (20, 12)
# currently looking at node = (21, 13)
# currently looking at node = (22, 14)
# currently looking at node = (20, 13)
# currently looking at node = (21, 14)
# currently looking at node = (22, 15)
# currently looking at node = (20, 14)
# currently looking at node = (21, 15)
# currently looking at node = (22, 16)
# currently looking at node = (20, 15)
# currently looking at node = (21, 16)
# currently looking at node = (22, 17)
# currently looking at node = (20, 16)
# currently looking at node = (21, 17)
# currently looking at node = (22, 18)
# currently looking at node = (20, 17)
# currently looking at node = (21, 18)
# currently looking at node = (22, 19)
# currently looking at node = (20, 18)
# currently looking at node = (21, 19)
# currently looking at node = (22, 20)
# currently looking at node = (20, 19)
# currently looking at node = (21, 20)
# currently looking at node = (22, 21)
# currently looking at node = (20, 20)
# currently looking at node = (21, 21)
# currently looking at node = (22, 22)
# currently looking at node = (20, 21)
# currently looking at node = (21, 22)
# currently looking at node = (22, 23)
# currently looking at node = (20, 22)
# currently looking at node = (21, 23)
# currently looking at node = (22, 24)
# currently looking at node = (20, 23)
# currently looking at node = (21, 24)
# currently looking at node = (22, 25)
# currently looking at node = (20, 24)
# currently looking at node = (21, 25)
# currently looking at node = (22, 26)
# currently looking at node = (20, 25)
# currently looking at node = (21, 26)
# currently looking at node = (22, 27)
# currently looking at node = (20, 26)
# currently looking at node = (21, 27)
# currently looking at node = (22, 28)
# currently looking at node = (20, 27)
# currently looking at node = (21, 28)
# currently looking at node = (22, 29)
# currently looking at node = (20, 28)
# currently looking at node = (21, 29)
# currently looking at node = (22, 30)
# currently looking at node = (20, 29)
# currently looking at node = (21, 30)
# currently looking at node = (22, 31)
# currently looking at node = (20, 30)
# currently looking at node = (21, 31)
# currently looking at node = (22, 32)
# currently looking at node = (20, 31)
# currently looking at node = (21, 32)
# currently looking at node = (22, 33)
# currently looking at node = (20, 32)
# currently looking at node = (21, 33)
# currently looking at node = (22, 34)
# currently looking at node = (20, 33)
# currently looking at node = (21, 34)
# currently looking at node = (22, 35)
# currently looking at node = (20, 34)
# currently looking at node = (21, 35)
# currently looking at node = (22, 36)
# currently looking at node = (20, 35)
# currently looking at node = (21, 36)
# currently looking at node = (22, 37)
# currently looking at node = (20, 36)
# currently looking at node = (21, 37)
# currently looking at node = (22, 38)
# currently looking at node = (20, 37)
# currently looking at node = (21, 38)
# currently looking at node = (22, 39)
# currently looking at node = (20, 38)
# currently looking at node = (21, 39)
# currently looking at node = (22, 40)
# currently looking at node = (20, 39)
# currently looking at node = (21, 40)
# currently looking at node = (20, 40)
# currently looking at node = (21, 41)
# currently looking at node = (20, 41)
# currently looking at node = (21, 42)
# currently looking at node = (20, 42)
# currently looking at node = (20, 43)
# currently looking at node = (17, 0)
# currently looking at node = (23, 0)
# currently looking at node = (17, 1)
# currently looking at node = (23, 1)
# currently looking at node = (17, 2)
# currently looking at node = (23, 2)
# currently looking at node = (17, 3)
# currently looking at node = (23, 3)
# currently looking at node = (17, 4)
# currently looking at node = (17, 5)
# currently looking at node = (17, 6)
# currently looking at node = (17, 7)
# currently looking at node = (17, 8)
# currently looking at node = (17, 9)
# currently looking at node = (17, 10)
# currently looking at node = (23, 4)
# currently looking at node = (23, 5)
# currently looking at node = (23, 6)
# currently looking at node = (23, 7)
# currently looking at node = (23, 8)
# currently looking at node = (23, 9)
# currently looking at node = (23, 10)
# currently looking at node = (23, 11)
# currently looking at node = (23, 12)
# currently looking at node = (23, 13)
# currently looking at node = (19, 12)
# currently looking at node = (23, 14)
# currently looking at node = (19, 13)
# currently looking at node = (23, 15)
# currently looking at node = (19, 14)
# currently looking at node = (23, 16)
# currently looking at node = (19, 15)
# currently looking at node = (23, 17)
# currently looking at node = (19, 16)
# currently looking at node = (23, 18)
# currently looking at node = (19, 17)
# currently looking at node = (23, 19)
# currently looking at node = (19, 18)
# currently looking at node = (23, 20)
# currently looking at node = (19, 19)
# currently looking at node = (23, 21)
# currently looking at node = (19, 20)
# currently looking at node = (23, 22)
# currently looking at node = (19, 21)
# currently looking at node = (23, 23)
# currently looking at node = (19, 22)
# currently looking at node = (23, 24)
# currently looking at node = (19, 23)
# currently looking at node = (23, 25)
# currently looking at node = (19, 24)
# currently looking at node = (23, 26)
# currently looking at node = (19, 25)
# currently looking at node = (23, 27)
# currently looking at node = (19, 26)
# currently looking at node = (23, 28)
# currently looking at node = (19, 27)
# currently looking at node = (23, 29)
# currently looking at node = (19, 28)
# currently looking at node = (23, 30)
# currently looking at node = (19, 29)
# currently looking at node = (23, 31)
# currently looking at node = (19, 30)
# currently looking at node = (23, 32)
# currently looking at node = (19, 31)
# currently looking at node = (23, 33)
# currently looking at node = (19, 32)
# currently looking at node = (23, 34)
# currently looking at node = (19, 33)
# currently looking at node = (23, 35)
# currently looking at node = (19, 34)
# currently looking at node = (23, 36)
# currently looking at node = (19, 35)
# currently looking at node = (23, 37)
# currently looking at node = (19, 36)
# currently looking at node = (23, 38)
# currently looking at node = (19, 37)
# currently looking at node = (23, 39)
# currently looking at node = (19, 38)
# currently looking at node = (23, 40)
# currently looking at node = (19, 39)
# currently looking at node = (19, 40)
# currently looking at node = (19, 41)
# currently looking at node = (19, 42)
# currently looking at node = (16, 0)
# currently looking at node = (24, 0)
# currently looking at node = (16, 1)
# currently looking at node = (24, 1)
# currently looking at node = (16, 2)
# currently looking at node = (24, 2)
# currently looking at node = (16, 3)
# currently looking at node = (24, 3)
# currently looking at node = (16, 4)
# currently looking at node = (16, 5)
# currently looking at node = (16, 6)
# currently looking at node = (16, 7)
# currently looking at node = (16, 8)
# currently looking at node = (16, 9)
# currently looking at node = (16, 10)
# currently looking at node = (24, 4)
# currently looking at node = (24, 5)
# currently looking at node = (24, 6)
# currently looking at node = (24, 7)
# currently looking at node = (24, 8)
# currently looking at node = (24, 9)
# currently looking at node = (24, 10)
# currently looking at node = (24, 11)
# currently looking at node = (24, 12)
# currently looking at node = (24, 13)
# currently looking at node = (18, 12)
# currently looking at node = (24, 14)
# currently looking at node = (18, 13)
# currently looking at node = (24, 15)
# currently looking at node = (18, 14)
# currently looking at node = (24, 16)
# currently looking at node = (18, 15)
# currently looking at node = (24, 17)
# currently looking at node = (18, 16)
# currently looking at node = (24, 18)
# currently looking at node = (18, 17)
# currently looking at node = (24, 19)
# currently looking at node = (18, 18)
# currently looking at node = (24, 20)
# currently looking at node = (18, 19)
# currently looking at node = (24, 21)
# currently looking at node = (18, 20)
# currently looking at node = (24, 22)
# currently looking at node = (18, 21)
# currently looking at node = (24, 23)
# currently looking at node = (18, 22)
# currently looking at node = (24, 24)
# currently looking at node = (18, 23)
# currently looking at node = (24, 25)
# currently looking at node = (18, 24)
# currently looking at node = (24, 26)
# currently looking at node = (18, 25)
# currently looking at node = (24, 27)
# currently looking at node = (18, 26)
# currently looking at node = (24, 28)
# currently looking at node = (18, 27)
# currently looking at node = (24, 29)
# currently looking at node = (18, 28)
# currently looking at node = (24, 30)
# currently looking at node = (18, 29)
# currently looking at node = (24, 31)
# currently looking at node = (18, 30)
# currently looking at node = (24, 32)
# currently looking at node = (18, 31)
# currently looking at node = (24, 33)
# currently looking at node = (18, 32)
# currently looking at node = (24, 34)
# currently looking at node = (18, 33)
# currently looking at node = (24, 35)
# currently looking at node = (18, 34)
# currently looking at node = (24, 36)
# currently looking at node = (18, 35)
# currently looking at node = (18, 36)
# currently looking at node = (24, 38)
# currently looking at node = (18, 37)
# currently looking at node = (24, 39)
# currently looking at node = (18, 38)
# currently looking at node = (24, 40)
# currently looking at node = (18, 39)
# currently looking at node = (15, 0)
# currently looking at node = (25, 0)
# currently looking at node = (15, 1)
# currently looking at node = (25, 1)
# currently looking at node = (25, 2)
# currently looking at node = (15, 3)
# currently looking at node = (25, 3)
# currently looking at node = (15, 4)
# currently looking at node = (15, 5)
# currently looking at node = (15, 6)
# currently looking at node = (15, 7)
# currently looking at node = (15, 8)
# currently looking at node = (15, 9)
# currently looking at node = (15, 10)
# currently looking at node = (25, 4)
# currently looking at node = (25, 5)
# currently looking at node = (25, 6)
# currently looking at node = (25, 7)
# currently looking at node = (25, 8)
# currently looking at node = (25, 9)
# currently looking at node = (25, 10)
# currently looking at node = (25, 11)
# currently looking at node = (25, 12)
# currently looking at node = (25, 13)
# currently looking at node = (17, 12)
# currently looking at node = (18, 11)
# currently looking at node = (25, 14)
# currently looking at node = (17, 13)
# currently looking at node = (25, 15)
# currently looking at node = (17, 14)
# currently looking at node = (25, 16)
# currently looking at node = (17, 15)
# currently looking at node = (25, 17)
# currently looking at node = (17, 16)
# currently looking at node = (25, 18)
# currently looking at node = (17, 17)
# currently looking at node = (25, 19)
# currently looking at node = (17, 18)
# currently looking at node = (25, 20)
# currently looking at node = (17, 19)
# currently looking at node = (25, 21)
# currently looking at node = (25, 22)
# currently looking at node = (17, 21)
# currently looking at node = (25, 23)
# currently looking at node = (17, 22)
# currently looking at node = (25, 24)
# currently looking at node = (17, 23)
# currently looking at node = (25, 25)
# currently looking at node = (17, 24)
# currently looking at node = (25, 26)
# currently looking at node = (17, 25)
# currently looking at node = (25, 27)
# currently looking at node = (17, 26)
# currently looking at node = (25, 28)
# currently looking at node = (17, 27)
# currently looking at node = (25, 29)
# currently looking at node = (17, 28)
# currently looking at node = (25, 30)
# currently looking at node = (17, 29)
# currently looking at node = (25, 31)
# currently looking at node = (17, 30)
# currently looking at node = (25, 32)
# currently looking at node = (17, 31)
# currently looking at node = (25, 33)
# currently looking at node = (25, 34)
# currently looking at node = (17, 33)
# currently looking at node = (25, 35)
# currently looking at node = (17, 34)
# currently looking at node = (25, 36)
# currently looking at node = (17, 35)
# currently looking at node = (17, 36)
# currently looking at node = (17, 37)
# currently looking at node = (25, 39)
# currently looking at node = (17, 38)
# currently looking at node = (25, 40)
# currently looking at node = (17, 39)
# currently looking at node = (15, 2)
# currently looking at node = (17, 32)
# currently looking at node = (17, 40)
# currently looking at node = (14, 0)
# currently looking at node = (26, 0)
# currently looking at node = (14, 1)
# currently looking at node = (26, 1)
# currently looking at node = (26, 2)
# currently looking at node = (26, 3)
# currently looking at node = (14, 4)
# currently looking at node = (14, 5)
# currently looking at node = (14, 6)
# currently looking at node = (14, 7)
# currently looking at node = (14, 8)
# currently looking at node = (14, 9)
# currently looking at node = (14, 10)
# currently looking at node = (26, 4)
# currently looking at node = (26, 5)
# currently looking at node = (26, 6)
# currently looking at node = (26, 7)
# currently looking at node = (26, 8)
# currently looking at node = (26, 9)
# currently looking at node = (26, 10)
# currently looking at node = (26, 11)
# currently looking at node = (26, 12)
# currently looking at node = (26, 13)
# currently looking at node = (16, 12)
# currently looking at node = (17, 11)
# currently looking at node = (26, 14)
# currently looking at node = (26, 15)
# currently looking at node = (26, 16)
# currently looking at node = (16, 15)
# currently looking at node = (26, 17)
# currently looking at node = (16, 16)
# currently looking at node = (26, 18)
# currently looking at node = (16, 17)
# currently looking at node = (26, 19)
# currently looking at node = (16, 18)
# currently looking at node = (26, 20)
# currently looking at node = (16, 19)
# currently looking at node = (26, 21)
# currently looking at node = (26, 22)
# currently looking at node = (16, 21)
# currently looking at node = (26, 23)
# currently looking at node = (16, 22)
# currently looking at node = (26, 24)
# currently looking at node = (16, 23)
# currently looking at node = (26, 25)
# currently looking at node = (16, 24)
# currently looking at node = (26, 26)
# currently looking at node = (16, 25)
# currently looking at node = (26, 27)
# currently looking at node = (26, 28)
# currently looking at node = (16, 27)
# currently looking at node = (26, 29)
# currently looking at node = (16, 28)
# currently looking at node = (26, 30)
# currently looking at node = (16, 29)
# currently looking at node = (26, 31)
# currently looking at node = (16, 30)
# currently looking at node = (26, 32)
# currently looking at node = (16, 31)
# currently looking at node = (26, 34)
# currently looking at node = (16, 33)
# currently looking at node = (26, 35)
# currently looking at node = (16, 34)
# currently looking at node = (26, 36)
# currently looking at node = (16, 35)
# currently looking at node = (16, 36)
# currently looking at node = (16, 37)
# currently looking at node = (16, 38)
# currently looking at node = (16, 39)
# currently looking at node = (14, 2)
# currently looking at node = (16, 32)
# currently looking at node = (14, 11)
# currently looking at node = (16, 13)
# currently looking at node = (26, 33)
# currently looking at node = (14, 3)
# currently looking at node = (16, 14)
# currently looking at node = (13, 0)
# currently looking at node = (27, 0)
# currently looking at node = (13, 1)
# currently looking at node = (27, 1)
# currently looking at node = (27, 3)
# currently looking at node = (13, 5)
# currently looking at node = (13, 6)
# currently looking at node = (13, 7)
# currently looking at node = (13, 10)
# currently looking at node = (27, 4)
# currently looking at node = (27, 5)
# currently looking at node = (27, 6)
# currently looking at node = (27, 7)
# currently looking at node = (27, 8)
# currently looking at node = (27, 9)
# currently looking at node = (27, 10)
# currently looking at node = (27, 11)
# currently looking at node = (27, 12)
# currently looking at node = (27, 13)
# currently looking at node = (15, 12)
# currently looking at node = (16, 11)
# currently looking at node = (27, 14)
# currently looking at node = (27, 15)
# currently looking at node = (27, 16)
# currently looking at node = (15, 15)
# currently looking at node = (27, 17)
# currently looking at node = (15, 16)
# currently looking at node = (27, 18)
# currently looking at node = (15, 17)
# currently looking at node = (27, 19)
# currently looking at node = (15, 18)
# currently looking at node = (27, 20)
# currently looking at node = (15, 19)
# currently looking at node = (27, 21)
# currently looking at node = (27, 22)
# currently looking at node = (15, 21)
# currently looking at node = (27, 23)
# currently looking at node = (15, 22)
# currently looking at node = (27, 24)
# currently looking at node = (15, 23)
# currently looking at node = (27, 25)
# currently looking at node = (15, 24)
# currently looking at node = (27, 26)
# currently looking at node = (15, 25)
# currently looking at node = (27, 27)
# currently looking at node = (27, 28)
# currently looking at node = (15, 27)
# currently looking at node = (16, 26)
# currently looking at node = (27, 29)
# currently looking at node = (15, 28)
# currently looking at node = (27, 30)
# currently looking at node = (15, 29)
# currently looking at node = (27, 31)
# currently looking at node = (15, 30)
# currently looking at node = (27, 32)
# currently looking at node = (15, 31)
# currently looking at node = (15, 33)
# currently looking at node = (15, 34)
# currently looking at node = (15, 35)
# currently looking at node = (15, 36)
# currently looking at node = (15, 37)
# currently looking at node = (13, 2)
# currently looking at node = (15, 32)
# currently looking at node = (15, 13)
# currently looking at node = (27, 33)
# currently looking at node = (13, 3)
# currently looking at node = (15, 14)
# currently looking at node = (27, 2)
# currently looking at node = (27, 34)
# currently looking at node = (13, 4)
# currently looking at node = (27, 35)
# currently looking at node = (27, 36)
# currently looking at node = (27, 37)
# currently looking at node = (26, 37)
# currently looking at node = (27, 38)
# currently looking at node = (25, 37)
# currently looking at node = (26, 38)
# currently looking at node = (27, 39)
# currently looking at node = (24, 37)
# currently looking at node = (25, 38)
# currently looking at node = (26, 39)
# currently looking at node = (27, 40)
# currently looking at node = (26, 40)
# currently looking at node = (27, 41)
# currently looking at node = (26, 41)
# currently looking at node = (27, 42)
# currently looking at node = (25, 41)
# currently looking at node = (26, 42)
# currently looking at node = (27, 43)
# currently looking at node = (24, 41)
# currently looking at node = (25, 42)
# currently looking at node = (26, 43)
# currently looking at node = (27, 44)
# currently looking at node = (23, 41)
# currently looking at node = (24, 42)
# currently looking at node = (25, 43)
# currently looking at node = (26, 44)
# currently looking at node = (27, 45)
# currently looking at node = (22, 41)
# currently looking at node = (23, 42)
# currently looking at node = (24, 43)
# currently looking at node = (25, 44)
# currently looking at node = (26, 45)
# currently looking at node = (27, 46)
# currently looking at node = (22, 42)
# currently looking at node = (23, 43)
# currently looking at node = (24, 44)
# currently looking at node = (25, 45)
# currently looking at node = (26, 46)
# currently looking at node = (27, 47)
# currently looking at node = (22, 43)
# currently looking at node = (23, 44)
# currently looking at node = (25, 46)
# currently looking at node = (26, 47)
# currently looking at node = (27, 48)
# currently looking at node = (21, 43)
# currently looking at node = (22, 44)
# currently looking at node = (23, 45)
# currently looking at node = (25, 47)
# currently looking at node = (26, 48)
# currently looking at node = (27, 49)
# currently looking at node = (21, 44)
# currently looking at node = (22, 45)
# currently looking at node = (23, 46)
# currently looking at node = (24, 47)
# currently looking at node = (25, 48)
# currently looking at node = (26, 49)
# currently looking at node = (27, 50)
# currently looking at node = (20, 44)
# currently looking at node = (21, 45)
# currently looking at node = (22, 46)
# currently looking at node = (23, 47)
# currently looking at node = (24, 48)
# currently looking at node = (25, 49)
# currently looking at node = (20, 45)
# currently looking at node = (21, 46)
# currently looking at node = (22, 47)
# currently looking at node = (23, 48)
# currently looking at node = (24, 49)
# currently looking at node = (20, 46)
# currently looking at node = (21, 47)
# currently looking at node = (22, 48)
# currently looking at node = (23, 49)
# currently looking at node = (20, 47)
# currently looking at node = (21, 48)
# currently looking at node = (22, 49)
# currently looking at node = (23, 50)
# currently looking at node = (20, 48)
# currently looking at node = (21, 49)
# currently looking at node = (22, 50)
# currently looking at node = (23, 51)
# currently looking at node = (20, 49)
# currently looking at node = (21, 50)
# currently looking at node = (22, 51)
# currently looking at node = (23, 52)
# currently looking at node = (20, 50)
# currently looking at node = (21, 51)
# currently looking at node = (22, 52)
# currently looking at node = (23, 53)
# currently looking at node = (20, 51)
# currently looking at node = (21, 52)
# currently looking at node = (22, 53)
# currently looking at node = (23, 54)
# currently looking at node = (20, 52)
# currently looking at node = (21, 53)
# currently looking at node = (22, 54)
# currently looking at node = (23, 55)
# currently looking at node = (20, 53)
# currently looking at node = (21, 54)
# currently looking at node = (22, 55)
# currently looking at node = (23, 56)
# currently looking at node = (20, 54)
# currently looking at node = (21, 55)
# currently looking at node = (22, 56)
# currently looking at node = (23, 57)
# currently looking at node = (20, 55)
# currently looking at node = (21, 56)
# currently looking at node = (22, 57)
# currently looking at node = (23, 58)
# currently looking at node = (20, 56)
# currently looking at node = (21, 57)
# currently looking at node = (22, 58)
# currently looking at node = (20, 57)
# currently looking at node = (21, 58)
# currently looking at node = (22, 59)
# currently looking at node = (20, 58)
# currently looking at node = (21, 59)
# currently looking at node = (22, 60)
# currently looking at node = (20, 59)
# currently looking at node = (21, 60)
# currently looking at node = (20, 60)
# currently looking at node = (12, 0)
# currently looking at node = (28, 0)
# currently looking at node = (12, 1)
# currently looking at node = (28, 1)
# currently looking at node = (28, 3)
# currently looking at node = (12, 5)
# currently looking at node = (12, 6)
# currently looking at node = (28, 4)
# currently looking at node = (28, 5)
# currently looking at node = (28, 8)
# currently looking at node = (28, 9)
# currently looking at node = (28, 10)
# currently looking at node = (28, 11)
# currently looking at node = (28, 12)
# currently looking at node = (28, 13)
# currently looking at node = (14, 12)
# currently looking at node = (15, 11)
# currently looking at node = (28, 14)
# currently looking at node = (28, 15)
# currently looking at node = (28, 16)
# currently looking at node = (14, 15)
# currently looking at node = (28, 17)
# currently looking at node = (14, 16)
# currently looking at node = (28, 18)
# currently looking at node = (14, 17)
# currently looking at node = (28, 19)
# currently looking at node = (28, 20)
# currently looking at node = (28, 21)
# currently looking at node = (28, 22)
# currently looking at node = (28, 23)
# currently looking at node = (28, 24)
# currently looking at node = (28, 25)
# currently looking at node = (28, 26)
# currently looking at node = (28, 27)
# currently looking at node = (28, 28)
# currently looking at node = (14, 27)
# currently looking at node = (15, 26)
# currently looking at node = (28, 29)
# currently looking at node = (14, 28)
# currently looking at node = (28, 30)
# currently looking at node = (14, 29)
# currently looking at node = (28, 31)
# currently looking at node = (14, 30)
# currently looking at node = (28, 32)
# currently looking at node = (14, 31)
# currently looking at node = (14, 34)
# currently looking at node = (14, 35)
# currently looking at node = (14, 36)
# currently looking at node = (12, 2)
# currently looking at node = (14, 13)
# currently looking at node = (28, 33)
# currently looking at node = (12, 3)
# currently looking at node = (28, 2)
# currently looking at node = (28, 34)
# currently looking at node = (12, 4)
# currently looking at node = (28, 35)
# currently looking at node = (28, 36)
# currently looking at node = (28, 37)
# currently looking at node = (28, 38)
# currently looking at node = (28, 39)
# currently looking at node = (28, 40)
# currently looking at node = (28, 41)
# currently looking at node = (28, 42)
# currently looking at node = (28, 43)
# currently looking at node = (28, 44)
# currently looking at node = (28, 45)
# currently looking at node = (28, 46)
# currently looking at node = (28, 47)
# currently looking at node = (28, 48)
# currently looking at node = (24, 45)
# currently looking at node = (28, 49)
# currently looking at node = (24, 46)
# currently looking at node = (28, 50)
# currently looking at node = (19, 44)
# currently looking at node = (19, 45)
# currently looking at node = (19, 46)
# currently looking at node = (19, 47)
# currently looking at node = (24, 50)
# currently looking at node = (19, 48)
# currently looking at node = (24, 51)
# currently looking at node = (19, 49)
# currently looking at node = (24, 52)
# currently looking at node = (19, 50)
# currently looking at node = (24, 53)
# currently looking at node = (19, 51)
# currently looking at node = (24, 54)
# currently looking at node = (19, 52)
# currently looking at node = (24, 55)
# currently looking at node = (19, 53)
# currently looking at node = (24, 56)
# currently looking at node = (19, 54)
# currently looking at node = (19, 55)
# currently looking at node = (19, 56)
# currently looking at node = (19, 57)
# currently looking at node = (19, 58)
# currently looking at node = (19, 59)
# currently looking at node = (14, 32)
# currently looking at node = (14, 14)
# currently looking at node = (24, 57)
# currently looking at node = (14, 33)
# currently looking at node = (24, 58)
# currently looking at node = (24, 59)
# currently looking at node = (23, 59)
# currently looking at node = (24, 60)
# currently looking at node = (23, 60)
# currently looking at node = (24, 61)
# currently looking at node = (23, 61)
# currently looking at node = (24, 62)
# currently looking at node = (22, 61)
# currently looking at node = (23, 62)
# currently looking at node = (24, 63)
# currently looking at node = (21, 61)
# currently looking at node = (22, 62)
# currently looking at node = (23, 63)
# currently looking at node = (24, 64)
# currently looking at node = (20, 61)
# currently looking at node = (21, 62)
# currently looking at node = (22, 63)
# currently looking at node = (23, 64)
# currently looking at node = (24, 65)
# currently looking at node = (20, 62)
# currently looking at node = (21, 63)
# currently looking at node = (22, 64)
# currently looking at node = (23, 65)
# currently looking at node = (24, 66)
# currently looking at node = (20, 63)
# currently looking at node = (21, 64)
# currently looking at node = (22, 65)
# currently looking at node = (23, 66)
# currently looking at node = (24, 67)
# currently looking at node = (20, 64)
# currently looking at node = (21, 65)
# currently looking at node = (22, 66)
# currently looking at node = (23, 67)
# currently looking at node = (24, 68)
# currently looking at node = (20, 65)
# currently looking at node = (21, 66)
# currently looking at node = (22, 67)
# currently looking at node = (23, 68)
# currently looking at node = (24, 69)
# currently looking at node = (20, 66)
# currently looking at node = (21, 67)
# currently looking at node = (22, 68)
# currently looking at node = (23, 69)
# currently looking at node = (24, 70)
# currently looking at node = (20, 67)
# currently looking at node = (21, 68)
# currently looking at node = (22, 69)
# currently looking at node = (23, 70)
# currently looking at node = (24, 71)
# currently looking at node = (20, 68)
# currently looking at node = (21, 69)
# currently looking at node = (22, 70)
# currently looking at node = (23, 71)
# currently looking at node = (24, 72)
# currently looking at node = (20, 69)
# currently looking at node = (21, 70)
# currently looking at node = (22, 71)
# currently looking at node = (23, 72)
# currently looking at node = (24, 73)
# currently looking at node = (20, 70)
# currently looking at node = (21, 71)
# currently looking at node = (22, 72)
# currently looking at node = (23, 73)
# currently looking at node = (24, 74)
# currently looking at node = (20, 71)
# currently looking at node = (21, 72)
# currently looking at node = (22, 73)
# currently looking at node = (23, 74)
# currently looking at node = (24, 75)
# currently looking at node = (20, 72)
# currently looking at node = (21, 73)
# currently looking at node = (22, 74)
# currently looking at node = (23, 75)
# currently looking at node = (24, 76)
# currently looking at node = (20, 73)
# currently looking at node = (21, 74)
# currently looking at node = (22, 75)
# currently looking at node = (23, 76)
# currently looking at node = (24, 77)
# currently looking at node = (20, 74)
# currently looking at node = (21, 75)
# currently looking at node = (22, 76)
# currently looking at node = (23, 77)
# currently looking at node = (20, 75)
# currently looking at node = (21, 76)
# currently looking at node = (22, 77)
# currently looking at node = (23, 78)
# currently looking at node = (20, 76)
# currently looking at node = (21, 77)
# currently looking at node = (22, 78)
# currently looking at node = (23, 79)
# currently looking at node = (20, 77)
# currently looking at node = (21, 78)
# currently looking at node = (22, 79)
# currently looking at node = (23, 80)
# currently looking at node = (20, 78)
# currently looking at node = (21, 79)
# currently looking at node = (22, 80)
# currently looking at node = (23, 81)
# currently looking at node = (20, 79)
# currently looking at node = (21, 80)
# currently looking at node = (22, 81)
# currently looking at node = (23, 82)
# currently looking at node = (20, 80)
# currently looking at node = (21, 81)
# currently looking at node = (22, 82)
# currently looking at node = (23, 83)
# currently looking at node = (21, 82)
# currently looking at node = (22, 83)
# currently looking at node = (23, 84)
# currently looking at node = (20, 82)
# currently looking at node = (21, 83)
# currently looking at node = (22, 84)
# currently looking at node = (23, 85)
# currently looking at node = (20, 83)
# currently looking at node = (21, 84)
# currently looking at node = (22, 85)
# currently looking at node = (23, 86)
# currently looking at node = (20, 84)
# currently looking at node = (21, 85)
# currently looking at node = (22, 86)
# currently looking at node = (23, 87)
# currently looking at node = (20, 85)
# currently looking at node = (22, 87)
# currently looking at node = (23, 88)
# currently looking at node = (20, 86)
# currently looking at node = (22, 88)
# currently looking at node = (20, 87)
# currently looking at node = (22, 89)
# currently looking at node = (20, 88)
# currently looking at node = (20, 89)
# currently looking at node = (20, 90)
# currently looking at node = (20, 91)
# currently looking at node = (20, 92)
# currently looking at node = (20, 93)
# currently looking at node = (20, 94)
# currently looking at node = (20, 95)
# currently looking at node = (20, 96)
# currently looking at node = (20, 97)
# currently looking at node = (20, 98)
# currently looking at node = (11, 0)
# currently looking at node = (29, 0)
# currently looking at node = (11, 1)
# currently looking at node = (29, 1)
# currently looking at node = (29, 8)
# currently looking at node = (28, 7)
# currently looking at node = (29, 9)
# currently looking at node = (29, 10)
# currently looking at node = (29, 11)
# currently looking at node = (29, 12)
# currently looking at node = (29, 13)
# currently looking at node = (13, 12)
# currently looking at node = (29, 14)
# currently looking at node = (29, 15)
# currently looking at node = (29, 16)
# currently looking at node = (13, 15)
# currently looking at node = (29, 17)
# currently looking at node = (13, 16)
# currently looking at node = (29, 18)
# currently looking at node = (13, 17)
# currently looking at node = (29, 19)
# currently looking at node = (29, 20)
# currently looking at node = (29, 21)
# currently looking at node = (29, 22)
# currently looking at node = (29, 24)
# currently looking at node = (29, 25)
# currently looking at node = (29, 27)
# currently looking at node = (29, 28)
# currently looking at node = (13, 27)
# currently looking at node = (14, 26)
# currently looking at node = (29, 29)
# currently looking at node = (13, 28)
# currently looking at node = (29, 30)
# currently looking at node = (13, 29)
# currently looking at node = (29, 31)
# currently looking at node = (13, 30)
# currently looking at node = (29, 32)
# currently looking at node = (13, 31)
# currently looking at node = (11, 2)
# currently looking at node = (13, 13)
# currently looking at node = (29, 33)
# currently looking at node = (11, 3)
# currently looking at node = (29, 2)
# currently looking at node = (29, 34)
# currently looking at node = (29, 35)
# currently looking at node = (29, 36)
# currently looking at node = (29, 37)
# currently looking at node = (29, 38)
# currently looking at node = (29, 39)
# currently looking at node = (29, 40)
# currently looking at node = (29, 41)
# currently looking at node = (29, 42)
# currently looking at node = (29, 43)
# currently looking at node = (29, 44)
# currently looking at node = (29, 45)
# currently looking at node = (29, 46)
# currently looking at node = (29, 47)
# currently looking at node = (29, 48)
# currently looking at node = (29, 49)
# currently looking at node = (29, 50)
# currently looking at node = (18, 44)
# currently looking at node = (19, 43)
# currently looking at node = (18, 45)
# currently looking at node = (18, 46)
# currently looking at node = (18, 47)
# currently looking at node = (25, 50)
# currently looking at node = (18, 48)
# currently looking at node = (25, 51)
# currently looking at node = (18, 49)
# currently looking at node = (25, 52)
# currently looking at node = (18, 50)
# currently looking at node = (25, 53)
# currently looking at node = (18, 51)
# currently looking at node = (25, 54)
# currently looking at node = (18, 52)
# currently looking at node = (25, 55)
# currently looking at node = (18, 53)
# currently looking at node = (25, 56)
# currently looking at node = (18, 54)
# currently looking at node = (18, 56)
# currently looking at node = (18, 57)
# currently looking at node = (18, 58)
# currently looking at node = (18, 59)
# currently looking at node = (13, 32)
# currently looking at node = (13, 14)
# currently looking at node = (25, 57)
# currently looking at node = (13, 33)
# currently looking at node = (25, 58)
# currently looking at node = (25, 59)
# currently looking at node = (25, 60)
# currently looking at node = (25, 61)
# currently looking at node = (25, 62)
# currently looking at node = (25, 63)
# currently looking at node = (25, 64)
# currently looking at node = (19, 61)
# currently looking at node = (25, 65)
# currently looking at node = (19, 62)
# currently looking at node = (25, 66)
# currently looking at node = (19, 63)
# currently looking at node = (25, 67)
# currently looking at node = (19, 64)
# currently looking at node = (25, 68)
# currently looking at node = (19, 65)
# currently looking at node = (25, 69)
# currently looking at node = (19, 66)
# currently looking at node = (25, 70)
# currently looking at node = (19, 67)
# currently looking at node = (25, 71)
# currently looking at node = (19, 68)
# currently looking at node = (25, 72)
# currently looking at node = (19, 69)
# currently looking at node = (25, 73)
# currently looking at node = (19, 70)
# currently looking at node = (25, 74)
# currently looking at node = (19, 71)
# currently looking at node = (25, 75)
# currently looking at node = (19, 72)
# currently looking at node = (25, 76)
# currently looking at node = (19, 73)
# currently looking at node = (25, 77)
# currently looking at node = (19, 74)
# currently looking at node = (19, 75)
# currently looking at node = (24, 78)
# currently looking at node = (19, 76)
# currently looking at node = (24, 79)
# currently looking at node = (19, 77)
# currently looking at node = (24, 80)
# currently looking at node = (19, 78)
# currently looking at node = (24, 81)
# currently looking at node = (19, 79)
# currently looking at node = (24, 82)
# currently looking at node = (19, 80)
# currently looking at node = (24, 83)
# currently looking at node = (24, 84)
# currently looking at node = (19, 82)
# currently looking at node = (20, 81)
# currently looking at node = (24, 85)
# currently looking at node = (19, 83)
# currently looking at node = (24, 86)
# currently looking at node = (19, 84)
# currently looking at node = (24, 87)
# currently looking at node = (19, 85)
# currently looking at node = (24, 88)
# currently looking at node = (19, 86)
# currently looking at node = (21, 86)
# currently looking at node = (19, 87)
# currently looking at node = (21, 87)
# currently looking at node = (19, 88)
# currently looking at node = (21, 88)
# currently looking at node = (19, 89)
# currently looking at node = (21, 89)
# currently looking at node = (19, 90)
# currently looking at node = (21, 90)
# currently looking at node = (19, 91)
# currently looking at node = (21, 91)
# currently looking at node = (19, 92)
# currently looking at node = (21, 92)
# currently looking at node = (19, 93)
# currently looking at node = (21, 93)
# currently looking at node = (19, 94)
# currently looking at node = (21, 94)
# currently looking at node = (19, 95)
# currently looking at node = (21, 95)
# currently looking at node = (19, 96)
# currently looking at node = (21, 96)
# currently looking at node = (19, 97)
# currently looking at node = (19, 98)
# currently looking at node = (29, 23)
# currently looking at node = (11, 4)
# currently looking at node = (29, 3)
# currently looking at node = (18, 55)
# currently looking at node = (13, 34)
# currently looking at node = (25, 78)
# currently looking at node = (21, 97)
# currently looking at node = (11, 5)
# currently looking at node = (29, 4)
# currently looking at node = (13, 35)
# currently looking at node = (21, 98)
# currently looking at node = (11, 6)
# currently looking at node = (29, 5)
# currently looking at node = (13, 36)
# currently looking at node = (21, 99)
# currently looking at node = (11, 7)
# currently looking at node = (29, 6)
# currently looking at node = (29, 7)
# currently looking at node = (28, 6)
# currently looking at node = (13, 37)
# currently looking at node = (12, 7)
# currently looking at node = (11, 8)
# currently looking at node = (14, 37)
# currently looking at node = (13, 38)
# currently looking at node = (12, 8)
# currently looking at node = (11, 9)
# currently looking at node = (14, 38)
# currently looking at node = (13, 39)
# currently looking at node = (13, 8)
# currently looking at node = (12, 9)
# currently looking at node = (11, 10)
# currently looking at node = (15, 38)
# currently looking at node = (14, 39)
# currently looking at node = (13, 40)
# currently looking at node = (13, 9)
# currently looking at node = (12, 10)
# currently looking at node = (11, 11)
# currently looking at node = (15, 39)
# currently looking at node = (14, 40)
# currently looking at node = (13, 41)
# currently looking at node = (12, 11)
# currently looking at node = (12, 12)
# currently looking at node = (13, 11)
# currently looking at node = (12, 13)
# currently looking at node = (12, 14)
# currently looking at node = (12, 15)
# currently looking at node = (12, 16)
# currently looking at node = (11, 12)
# currently looking at node = (15, 40)
# currently looking at node = (14, 41)
# currently looking at node = (13, 42)
# currently looking at node = (11, 13)
# currently looking at node = (11, 14)
# currently looking at node = (11, 15)
# currently looking at node = (11, 16)
# currently looking at node = (16, 40)
# currently looking at node = (15, 41)
# currently looking at node = (14, 42)
# currently looking at node = (13, 43)
# currently looking at node = (11, 17)
# currently looking at node = (16, 41)
# currently looking at node = (15, 42)
# currently looking at node = (14, 43)
# currently looking at node = (13, 44)
# currently looking at node = (11, 18)
# currently looking at node = (17, 41)
# currently looking at node = (16, 42)
# currently looking at node = (15, 43)
# currently looking at node = (14, 44)
# currently looking at node = (11, 19)
# currently looking at node = (18, 41)
# currently looking at node = (17, 42)
# currently looking at node = (16, 43)
# currently looking at node = (15, 44)
# currently looking at node = (18, 42)
# currently looking at node = (18, 43)
# currently looking at node = (17, 43)
# currently looking at node = (17, 44)
# currently looking at node = (17, 45)
# currently looking at node = (17, 46)
# currently looking at node = (17, 47)
# currently looking at node = (17, 48)
# currently looking at node = (17, 49)
# currently looking at node = (17, 50)
# currently looking at node = (17, 51)
# currently looking at node = (16, 44)
# currently looking at node = (16, 45)
# currently looking at node = (16, 46)
# currently looking at node = (16, 47)
# currently looking at node = (16, 48)
# currently looking at node = (16, 49)
# currently looking at node = (16, 50)
# currently looking at node = (16, 51)
# currently looking at node = (10, 0)
# currently looking at node = (30, 0)
# currently looking at node = (10, 1)
# currently looking at node = (30, 1)
# currently looking at node = (30, 8)
# currently looking at node = (30, 9)
# currently looking at node = (30, 12)
# currently looking at node = (30, 13)
# currently looking at node = (30, 16)
# currently looking at node = (30, 17)
# currently looking at node = (30, 18)
# currently looking at node = (30, 19)
# currently looking at node = (30, 20)
# currently looking at node = (30, 21)
# currently looking at node = (30, 22)
# currently looking at node = (30, 27)
# currently looking at node = (29, 26)
# currently looking at node = (30, 28)
# currently looking at node = (12, 27)
# currently looking at node = (13, 26)
# currently looking at node = (14, 25)
# currently looking at node = (30, 29)
# currently looking at node = (12, 28)
# currently looking at node = (30, 30)
# currently looking at node = (12, 29)
# currently looking at node = (30, 31)
# currently looking at node = (12, 30)
# currently looking at node = (30, 32)
# currently looking at node = (12, 31)
# currently looking at node = (10, 2)
# currently looking at node = (30, 33)
# currently looking at node = (10, 3)
# currently looking at node = (30, 2)
# currently looking at node = (30, 34)
# currently looking at node = (30, 35)
# currently looking at node = (30, 36)
# currently looking at node = (30, 37)
# currently looking at node = (30, 38)
# currently looking at node = (30, 39)
# currently looking at node = (30, 40)
# currently looking at node = (30, 41)
# currently looking at node = (30, 42)
# currently looking at node = (30, 46)
# currently looking at node = (30, 47)
# currently looking at node = (30, 48)
# currently looking at node = (26, 50)
# currently looking at node = (26, 51)
# currently looking at node = (26, 52)
# currently looking at node = (26, 53)
# currently looking at node = (26, 54)
# currently looking at node = (17, 52)
# currently looking at node = (26, 55)
# currently looking at node = (17, 53)
# currently looking at node = (26, 56)
# currently looking at node = (17, 54)
# currently looking at node = (12, 32)
# currently looking at node = (26, 57)
# currently looking at node = (12, 33)
# currently looking at node = (26, 58)
# currently looking at node = (26, 59)
# currently looking at node = (26, 60)
# currently looking at node = (26, 61)
# currently looking at node = (26, 62)
# currently looking at node = (26, 63)
# currently looking at node = (26, 64)
# currently looking at node = (18, 61)
# currently looking at node = (19, 60)
# currently looking at node = (26, 65)
# currently looking at node = (18, 62)
# currently looking at node = (26, 66)
# currently looking at node = (18, 63)
# currently looking at node = (26, 67)
# currently looking at node = (18, 64)
# currently looking at node = (26, 68)
# currently looking at node = (18, 65)
# currently looking at node = (26, 69)
# currently looking at node = (18, 66)
# currently looking at node = (26, 70)
# currently looking at node = (26, 71)
# currently looking at node = (18, 68)
# currently looking at node = (26, 72)
# currently looking at node = (18, 69)
# currently looking at node = (26, 73)
# currently looking at node = (18, 70)
# currently looking at node = (26, 74)
# currently looking at node = (18, 71)
# currently looking at node = (26, 75)
# currently looking at node = (18, 72)
# currently looking at node = (26, 76)
# currently looking at node = (18, 73)
# currently looking at node = (26, 77)
# currently looking at node = (18, 74)
# currently looking at node = (18, 75)
# currently looking at node = (18, 76)
# currently looking at node = (25, 79)
# currently looking at node = (18, 77)
# currently looking at node = (25, 80)
# currently looking at node = (18, 78)
# currently looking at node = (25, 81)
# currently looking at node = (18, 79)
# currently looking at node = (25, 82)
# currently looking at node = (18, 80)
# currently looking at node = (25, 83)
# currently looking at node = (25, 84)
# currently looking at node = (18, 82)
# currently looking at node = (19, 81)
# currently looking at node = (25, 85)
# currently looking at node = (18, 83)
# currently looking at node = (25, 86)
# currently looking at node = (18, 84)
# currently looking at node = (25, 87)
# currently looking at node = (18, 85)
# currently looking at node = (25, 88)
# currently looking at node = (18, 86)
# currently looking at node = (18, 87)
# currently looking at node = (18, 88)
# currently looking at node = (18, 89)
# currently looking at node = (18, 90)
# currently looking at node = (22, 90)
# currently looking at node = (18, 91)
# currently looking at node = (22, 91)
# currently looking at node = (18, 92)
# currently looking at node = (22, 92)
# currently looking at node = (18, 93)
# currently looking at node = (22, 93)
# currently looking at node = (18, 94)
# currently looking at node = (22, 94)
# currently looking at node = (18, 95)
# currently looking at node = (22, 95)
# currently looking at node = (18, 96)
# currently looking at node = (22, 96)
# currently looking at node = (18, 97)
# currently looking at node = (18, 98)
# currently looking at node = (30, 23)
# currently looking at node = (10, 4)
# currently looking at node = (30, 3)
# currently looking at node = (17, 55)
# currently looking at node = (12, 34)
# currently looking at node = (26, 78)
# currently looking at node = (22, 97)
# currently looking at node = (10, 5)
# ...
# currently looking at node = (14, 124)
# currently looking at node = (12, 125)
# currently looking at node = (13, 125)
# currently looking at node = (14, 125)
# currently looking at node = (13, 126)
# currently looking at node = (14, 126)
# currently looking at node = (15, 126)
# currently looking at node = (16, 126)
# currently looking at node = (17, 126)
# currently looking at node = (18, 126)
# currently looking at node = (19, 126)
# currently looking at node = (20, 126)
# currently looking at node = (13, 127)
# currently looking at node = (14, 127)
# currently looking at node = (15, 127)
# currently looking at node = (16, 127)
# currently looking at node = (17, 127)
# currently looking at node = (18, 127)
# currently looking at node = (19, 127)
# currently looking at node = (21, 126)
# currently looking at node = (20, 127)
# currently looking at node = (21, 125)
# currently looking at node = (14, 128)
# currently looking at node = (15, 128)
# currently looking at node = (16, 128)
# currently looking at node = (17, 128)
# currently looking at node = (18, 128)
# currently looking at node = (19, 128)
# currently looking at node = (22, 126)
# currently looking at node = (21, 127)
# currently looking at node = (20, 128)
# currently looking at node = (22, 125)
# currently looking at node = (22, 124)
# currently looking at node = (23, 126)
# currently looking at node = (23, 125)
# currently looking at node = (23, 124)
# currently looking at node = (23, 123)
# currently looking at node = (24, 125)
# currently looking at node = (24, 124)
# currently looking at node = (24, 123)
# currently looking at node = (25, 125)
# currently looking at node = (25, 124)
# currently looking at node = (25, 123)
# currently looking at node = (26, 125)
# currently looking at node = (26, 124)
# currently looking at node = (27, 125)
# currently looking at node = (27, 124)
# currently looking at node = (28, 125)
# currently looking at node = (28, 124)
# currently looking at node = (28, 123)
# currently looking at node = (29, 125)
# currently looking at node = (29, 124)
# currently looking at node = (29, 123)
# currently looking at node = (30, 124)
# currently looking at node = (30, 123)
# currently looking at node = (30, 122)
# currently looking at node = (30, 121)
# currently looking at node = (31, 124)
# currently looking at node = (31, 123)
# currently looking at node = (31, 122)
# currently looking at node = (31, 121)
# currently looking at node = (31, 120)
# currently looking at node = (31, 119)
# currently looking at node = (31, 118)
# currently looking at node = (30, 118)
# currently looking at node = (31, 117)
# currently looking at node = (30, 117)
# currently looking at node = (31, 116)
# currently looking at node = (30, 116)
# currently looking at node = (31, 115)
# currently looking at node = (30, 115)
# currently looking at node = (31, 114)
# currently looking at node = (29, 115)
# currently looking at node = (30, 114)
# currently looking at node = (31, 113)
# currently looking at node = (29, 114)
# currently looking at node = (30, 113)
# currently looking at node = (31, 112)
# currently looking at node = (30, 112)
# currently looking at node = (32, 123)
# currently looking at node = (32, 122)
# currently looking at node = (32, 121)
# currently looking at node = (32, 120)
# currently looking at node = (32, 119)
# currently looking at node = (32, 118)
# currently looking at node = (32, 117)
# currently looking at node = (32, 113)
# currently looking at node = (32, 112)
# currently looking at node = (31, 111)
# currently looking at node = (32, 111)
# currently looking at node = (31, 110)
# currently looking at node = (32, 110)
# currently looking at node = (31, 109)
# currently looking at node = (30, 109)
# currently looking at node = (32, 109)
# currently looking at node = (31, 108)
# currently looking at node = (30, 108)
# currently looking at node = (32, 108)
# currently looking at node = (31, 107)
# currently looking at node = (30, 107)
# currently looking at node = (29, 107)
# currently looking at node = (28, 107)
# currently looking at node = (27, 107)
# currently looking at node = (26, 107)
# currently looking at node = (25, 107)
# currently looking at node = (24, 107)
# currently looking at node = (23, 107)
# currently looking at node = (32, 107)
# currently looking at node = (31, 106)
# currently looking at node = (30, 106)
# currently looking at node = (29, 106)
# currently looking at node = (28, 106)
# currently looking at node = (27, 106)
# currently looking at node = (26, 106)
# currently looking at node = (25, 106)
# currently looking at node = (24, 106)
# currently looking at node = (23, 106)
# currently looking at node = (22, 106)
# currently looking at node = (29, 105)
# currently looking at node = (28, 105)
# currently looking at node = (27, 105)
# currently looking at node = (26, 105)
# currently looking at node = (25, 105)
# currently looking at node = (24, 105)
# currently looking at node = (23, 105)
# currently looking at node = (22, 105)
# currently looking at node = (21, 105)
# currently looking at node = (23, 104)
# currently looking at node = (22, 104)
# currently looking at node = (21, 104)
# currently looking at node = (20, 104)
# currently looking at node = (21, 103)
# currently looking at node = (19, 104)
# currently looking at node = (20, 103)
# currently looking at node = (18, 104)
# currently looking at node = (19, 103)
# currently looking at node = (17, 104)
# currently looking at node = (18, 103)
# currently looking at node = (19, 102)
# currently looking at node = (17, 105)
# currently looking at node = (16, 104)
# currently looking at node = (17, 103)
# currently looking at node = (18, 102)
# currently looking at node = (16, 105)
# currently looking at node = (15, 104)
# currently looking at node = (16, 103)
# currently looking at node = (17, 102)
# currently looking at node = (15, 105)
# currently looking at node = (15, 106)
# currently looking at node = (15, 107)
# currently looking at node = (15, 108)
# currently looking at node = (15, 109)
# currently looking at node = (14, 105)
# currently looking at node = (14, 106)
# currently looking at node = (14, 107)
# currently looking at node = (14, 108)
# currently looking at node = (14, 109)
# currently looking at node = (14, 110)
# currently looking at node = (13, 108)
# currently looking at node = (13, 109)
# currently looking at node = (13, 110)
# currently looking at node = (13, 111)
# currently looking at node = (12, 109)
# currently looking at node = (12, 110)
# currently looking at node = (12, 111)
# currently looking at node = (12, 112)
# currently looking at node = (11, 110)
# currently looking at node = (11, 111)
# currently looking at node = (11, 112)
# currently looking at node = (10, 111)
# currently looking at node = (10, 112)
# currently looking at node = (9, 112)
# currently looking at node = (10, 113)
# currently looking at node = (9, 113)
# currently looking at node = (10, 114)
# currently looking at node = (8, 113)
# currently looking at node = (9, 114)
# currently looking at node = (10, 115)
# currently looking at node = (8, 114)
# currently looking at node = (9, 115)
# currently looking at node = (10, 116)
# currently looking at node = (11, 116)
# currently looking at node = (8, 115)
# currently looking at node = (9, 116)
# currently looking at node = (10, 117)
# currently looking at node = (11, 117)
# currently looking at node = (12, 117)
# currently looking at node = (11, 118)
# currently looking at node = (12, 118)
# currently looking at node = (13, 118)
# currently looking at node = (14, 118)
# currently looking at node = (12, 119)
# currently looking at node = (13, 119)
# currently looking at node = (14, 119)
# currently looking at node = (15, 119)
# currently looking at node = (13, 120)
# currently looking at node = (14, 120)
# currently looking at node = (15, 120)
# currently looking at node = (14, 121)
# currently looking at node = (15, 121)
# currently looking at node = (14, 122)
# currently looking at node = (15, 122)
# currently looking at node = (16, 122)
# currently looking at node = (14, 123)
# currently looking at node = (15, 123)
# currently looking at node = (16, 123)
# currently looking at node = (15, 124)
# currently looking at node = (16, 124)
# currently looking at node = (17, 124)
# currently looking at node = (18, 124)
# currently looking at node = (19, 124)
# currently looking at node = (20, 124)
# currently looking at node = (19, 123)
# currently looking at node = (20, 123)
# currently looking at node = (15, 125)
# currently looking at node = (16, 125)
# currently looking at node = (17, 125)
# currently looking at node = (18, 125)
# currently looking at node = (19, 125)
# currently looking at node = (21, 124)
# currently looking at node = (20, 125)
# currently looking at node = (21, 123)
# currently looking at node = (21, 122)
# currently looking at node = (22, 123)
# currently looking at node = (22, 122)
# currently looking at node = (22, 121)
# currently looking at node = (23, 122)
# currently looking at node = (23, 121)
# currently looking at node = (24, 122)
# currently looking at node = (24, 121)
# currently looking at node = (25, 122)
# currently looking at node = (25, 121)
# currently looking at node = (26, 122)
# currently looking at node = (26, 121)
# currently looking at node = (27, 122)
# currently looking at node = (26, 123)
# currently looking at node = (27, 121)
# currently looking at node = (28, 122)
# currently looking at node = (27, 123)
# currently looking at node = (28, 121)
# currently looking at node = (28, 120)
# currently looking at node = (28, 119)
# currently looking at node = (28, 118)
# currently looking at node = (28, 117)
# currently looking at node = (28, 116)
# currently looking at node = (27, 116)
# currently looking at node = (28, 115)
# currently looking at node = (27, 115)
# currently looking at node = (28, 114)
# currently looking at node = (26, 115)
# currently looking at node = (27, 114)
# currently looking at node = (28, 113)
# currently looking at node = (26, 114)
# currently looking at node = (27, 113)
# currently looking at node = (28, 112)
# currently looking at node = (29, 122)
# currently looking at node = (29, 121)
# currently looking at node = (29, 120)
# currently looking at node = (29, 119)
# currently looking at node = (29, 118)
# currently looking at node = (29, 117)
# currently looking at node = (29, 116)
# currently looking at node = (29, 113)
# currently looking at node = (29, 112)
# currently looking at node = (28, 111)
# currently looking at node = (30, 120)
# currently looking at node = (30, 119)
# currently looking at node = (29, 111)
# currently looking at node = (28, 110)
# currently looking at node = (27, 110)
# currently looking at node = (30, 111)
# currently looking at node = (29, 110)
# currently looking at node = (28, 109)
# currently looking at node = (27, 109)
# currently looking at node = (26, 109)
# currently looking at node = (25, 109)
# currently looking at node = (24, 109)
# currently looking at node = (23, 109)
# currently looking at node = (22, 109)
# currently looking at node = (21, 109)
# currently looking at node = (22, 110)
# currently looking at node = (30, 110)
# currently looking at node = (29, 109)
# currently looking at node = (28, 108)
# currently looking at node = (27, 108)
# currently looking at node = (26, 108)
# currently looking at node = (25, 108)
# currently looking at node = (24, 108)
# currently looking at node = (23, 108)
# currently looking at node = (22, 108)
# currently looking at node = (21, 108)
# currently looking at node = (29, 108)
# currently looking at node = (22, 107)
# currently looking at node = (21, 107)
# currently looking at node = (20, 107)
# currently looking at node = (21, 106)
# currently looking at node = (19, 107)
# currently looking at node = (20, 106)
# currently looking at node = (18, 107)
# currently looking at node = (19, 106)
# currently looking at node = (20, 105)
# currently looking at node = (18, 108)
# currently looking at node = (17, 107)
# currently looking at node = (18, 106)
# currently looking at node = (19, 105)
# currently looking at node = (17, 108)
# currently looking at node = (17, 109)
# currently looking at node = (17, 110)
# currently looking at node = (17, 111)
# currently looking at node = (17, 112)
# currently looking at node = (16, 107)
# currently looking at node = (17, 106)
# currently looking at node = (18, 105)
# currently looking at node = (16, 108)
# currently looking at node = (16, 109)
# currently looking at node = (16, 110)
# currently looking at node = (16, 111)
# currently looking at node = (16, 112)
# currently looking at node = (16, 106)
# currently looking at node = (15, 110)
# currently looking at node = (15, 111)
# currently looking at node = (15, 112)
# currently looking at node = (14, 111)
# currently looking at node = (14, 112)
# currently looking at node = (13, 112)
# currently looking at node = (14, 113)
# currently looking at node = (13, 113)
# currently looking at node = (12, 113)
# currently looking at node = (13, 114)
# currently looking at node = (11, 113)
# currently looking at node = (12, 114)
# currently looking at node = (13, 115)
# currently looking at node = (14, 115)
# currently looking at node = (11, 114)
# currently looking at node = (12, 115)
# currently looking at node = (13, 116)
# currently looking at node = (14, 116)
# currently looking at node = (15, 116)
# currently looking at node = (11, 115)
# currently looking at node = (12, 116)
# currently looking at node = (13, 117)
# currently looking at node = (14, 117)
# currently looking at node = (15, 117)
# currently looking at node = (16, 117)
# currently looking at node = (17, 117)
# currently looking at node = (15, 118)
# currently looking at node = (16, 118)
# currently looking at node = (17, 118)
# currently looking at node = (16, 119)
# currently looking at node = (17, 119)
# currently looking at node = (16, 120)
# currently looking at node = (17, 120)
# currently looking at node = (16, 121)
# currently looking at node = (17, 121)
# currently looking at node = (18, 121)
# currently looking at node = (19, 121)
# currently looking at node = (20, 121)
# currently looking at node = (20, 120)
# currently looking at node = (17, 122)
# currently looking at node = (18, 122)
# currently looking at node = (19, 122)
# currently looking at node = (21, 121)
# currently looking at node = (20, 122)
# currently looking at node = (21, 120)
# currently looking at node = (21, 119)
# currently looking at node = (21, 118)
# currently looking at node = (17, 123)
# currently looking at node = (18, 123)
# currently looking at node = (22, 120)
# currently looking at node = (22, 119)
# currently looking at node = (22, 118)
# currently looking at node = (23, 120)
# currently looking at node = (23, 119)
# currently looking at node = (24, 120)
# currently looking at node = (24, 119)
# currently looking at node = (25, 120)
# currently looking at node = (25, 119)
# currently looking at node = (25, 118)
# currently looking at node = (25, 117)
# currently looking at node = (25, 116)
# currently looking at node = (25, 115)
# currently looking at node = (24, 115)
# currently looking at node = (25, 114)
# currently looking at node = (24, 114)
# currently looking at node = (25, 113)
# currently looking at node = (25, 112)
# currently looking at node = (26, 120)
# currently looking at node = (26, 119)
# currently looking at node = (26, 118)
# currently looking at node = (26, 117)
# currently looking at node = (26, 116)
# currently looking at node = (26, 113)
# currently looking at node = (26, 112)
# currently looking at node = (25, 111)
# currently looking at node = (24, 111)
# currently looking at node = (23, 111)
# currently looking at node = (22, 111)
# currently looking at node = (23, 112)
# currently looking at node = (21, 111)
# currently looking at node = (22, 112)
# currently looking at node = (20, 111)
# currently looking at node = (21, 112)
# currently looking at node = (27, 120)
# currently looking at node = (27, 119)
# currently looking at node = (27, 118)
# currently looking at node = (27, 117)
# currently looking at node = (27, 112)
# currently looking at node = (26, 111)
# currently looking at node = (25, 110)
# currently looking at node = (24, 110)
# currently looking at node = (23, 110)
# currently looking at node = (24, 112)
# currently looking at node = (23, 113)
# currently looking at node = (21, 110)
# currently looking at node = (22, 113)
# currently looking at node = (19, 111)
# currently looking at node = (20, 110)
# currently looking at node = (21, 113)
# currently looking at node = (19, 112)
# currently looking at node = (20, 113)
# found end
# min distance = 456

# %% [markdown]
# ## Part 2

# %%
possible_starts = []
lengths_to_goal = []

for row_idx in range(row_num):
    for col_idx in range(col_num):
        if checkHeight((row_idx,col_idx)) == 1:
            possible_starts.append((row_idx,col_idx))
            
#print(f'possible_starts = {possible_starts}')

for pos_tuple in possible_starts:
    f_scores = {} #estimated distance to end (f_score = g_score + heuristic)
    g_scores = {} #distance from start

    #start = None
    end = None

    openSet = [] #unvisited
    closedSet = [] #visited

    print(f'starting location = {pos_tuple}')
    start = pos_tuple
    for row_idx in range(row_num):
        for col_idx in range(col_num):
            if lines[row_idx][col_idx] == 'S':
                g_scores[(row_idx,col_idx)] = float('inf')
                f_scores[(row_idx,col_idx)] = float('inf')
            elif lines[row_idx][col_idx] == 'E':
                end = (row_idx,col_idx)
                g_scores[end] = float('inf')
                f_scores[end] = float('inf')
            else:
                g_scores[(row_idx,col_idx)] = float('inf')
                f_scores[(row_idx,col_idx)] = float('inf')
    g_scores[start] = 0
    f_scores[start] = heuristic(start,end)
    openSet.append(start)
    counter = 0
    #print(f'start = {start}')
    #print(f'end = {end}')

    while openSet != []:

        counter += 1
        current = None
        best_f_score = float('inf')
        #print(f'openSet = {openSet}')
        for node in openSet:
            #print(f'node = {node} has f_score = {f_scores[node]}')
            #print(f'')
            if f_scores[node]<best_f_score:
                best_f_score = f_scores[node]
                current = node

        if current == None:
            print('SOMETHING WENT WRONG')
            break

        if current == end:
            #print('found end')
            #print(f'min distance = {f_scores[current]}')
            lengths_to_goal.append(f_scores[current])
            break

        #print(f'currently looking at node = {current}')

        openSet.remove(current)
        #check connected nodes 

        possible_neighbours = []

        if current[0]>0:
            #above
            possible_neighbours.append((current[0]-1,current[1]))

        if current[0]<row_num-1:
            #below
            possible_neighbours.append((current[0]+1,current[1]))

        if current[1]>0:
            #left
            possible_neighbours.append((current[0],current[1]-1))

        if current[1]<col_num-1:
            #right
            possible_neighbours.append((current[0],current[1]+1))

        #print(f'possible_neighbours = {possible_neighbours}')

        if current == start:
            current_height = 1
        else:
            current_height = checkHeight(current)

        neighbours_to_update = []

        for neighbour in possible_neighbours:
            if checkHeight(neighbour)-current_height <= 1:
                neighbours_to_update.append(neighbour)
        
        #print(f'neighbours_to_update = {neighbours_to_update}')
        #print(neighbours_to_update)

        for neighbour in neighbours_to_update:
            #print(f'current = {current}')
            #print(f'g_scores and f_scores for {current} = {g_scores[current]}, {f_scores[current]}')
            #print(f'checking neighbour: {neighbour}')
            if neighbour in closedSet:
                #print(f'neighbour: {neighbour} already been looked at... moving on')
                continue
            if neighbour not in openSet:
                openSet.append(neighbour)
            new_g_score = g_scores[current] + 1

            if new_g_score < g_scores[neighbour]:
                g_scores[neighbour] = new_g_score
                f_scores[neighbour] = new_g_score + heuristic(neighbour,end)
            #print(f'g_scores and f_scores for {neighbour} = {g_scores[neighbour]}, {f_scores[neighbour]}')

        closedSet.append(current)
        
print(f'best possible distance = {min(lengths_to_goal)}')
# Out:
# starting location = (0, 0)
# starting location = (0, 39)
# starting location = (0, 40)
# starting location = (0, 41)
# starting location = (0, 42)
# starting location = (0, 43)
# starting location = (0, 44)
# starting location = (0, 45)
# starting location = (0, 53)
# starting location = (0, 54)
# starting location = (0, 55)
# starting location = (0, 56)
# starting location = (0, 57)
# starting location = (0, 58)
# starting location = (0, 59)
# starting location = (0, 60)
# starting location = (0, 61)
# starting location = (0, 62)
# starting location = (0, 63)
# starting location = (0, 84)
# starting location = (0, 85)
# starting location = (0, 86)
# starting location = (0, 88)
# starting location = (0, 89)
# starting location = (0, 90)
# starting location = (0, 91)
# starting location = (0, 92)
# starting location = (0, 93)
# starting location = (0, 94)
# starting location = (0, 95)
# starting location = (0, 131)
# starting location = (0, 132)
# starting location = (0, 133)
# starting location = (0, 134)
# starting location = (0, 135)
# starting location = (1, 0)
# starting location = (1, 20)
# starting location = (1, 21)
# starting location = (1, 24)
# starting location = (1, 25)
# starting location = (1, 39)
# starting location = (1, 40)
# starting location = (1, 41)
# starting location = (1, 42)
# starting location = (1, 43)
# starting location = (1, 44)
# starting location = (1, 45)
# starting location = (1, 54)
# starting location = (1, 55)
# starting location = (1, 56)
# starting location = (1, 57)
# starting location = (1, 58)
# starting location = (1, 59)
# starting location = (1, 60)
# starting location = (1, 61)
# starting location = (1, 62)
# starting location = (1, 63)
# starting location = (1, 64)
# starting location = (1, 72)
# starting location = (1, 73)
# starting location = (1, 74)
# starting location = (1, 75)
# starting location = (1, 84)
# starting location = (1, 85)
# starting location = (1, 86)
# starting location = (1, 87)
# starting location = (1, 88)
# starting location = (1, 89)
# starting location = (1, 90)
# starting location = (1, 91)
# starting location = (1, 92)
# starting location = (1, 93)
# starting location = (1, 94)
# starting location = (1, 95)
# starting location = (1, 96)
# starting location = (1, 130)
# starting location = (1, 131)
# starting location = (1, 132)
# starting location = (1, 133)
# starting location = (1, 134)
# starting location = (1, 135)
# starting location = (2, 0)
# starting location = (2, 20)
# starting location = (2, 21)
# starting location = (2, 22)
# starting location = (2, 23)
# starting location = (2, 24)
# starting location = (2, 25)
# starting location = (2, 36)
# starting location = (2, 37)
# starting location = (2, 38)
# starting location = (2, 41)
# starting location = (2, 42)
# starting location = (2, 43)
# starting location = (2, 44)
# starting location = (2, 45)
# starting location = (2, 46)
# starting location = (2, 54)
# starting location = (2, 55)
# starting location = (2, 56)
# starting location = (2, 57)
# starting location = (2, 58)
# starting location = (2, 59)
# starting location = (2, 60)
# starting location = (2, 61)
# starting location = (2, 62)
# starting location = (2, 63)
# starting location = (2, 72)
# starting location = (2, 73)
# starting location = (2, 74)
# starting location = (2, 75)
# starting location = (2, 82)
# starting location = (2, 83)
# starting location = (2, 84)
# starting location = (2, 85)
# starting location = (2, 86)
# starting location = (2, 87)
# starting location = (2, 88)
# starting location = (2, 89)
# starting location = (2, 90)
# starting location = (2, 91)
# starting location = (2, 92)
# starting location = (2, 93)
# starting location = (2, 94)
# starting location = (2, 95)
# starting location = (2, 96)
# starting location = (2, 116)
# starting location = (2, 117)
# starting location = (2, 118)
# starting location = (2, 130)
# starting location = (2, 131)
# starting location = (2, 132)
# starting location = (2, 133)
# starting location = (2, 134)
# starting location = (2, 135)
# starting location = (3, 0)
# starting location = (3, 21)
# starting location = (3, 22)
# starting location = (3, 23)
# starting location = (3, 24)
# starting location = (3, 25)
# starting location = (3, 37)
# starting location = (3, 38)
# starting location = (3, 41)
# starting location = (3, 42)
# starting location = (3, 44)
# starting location = (3, 45)
# starting location = (3, 46)
# starting location = (3, 53)
# starting location = (3, 54)
# starting location = (3, 55)
# starting location = (3, 56)
# starting location = (3, 57)
# starting location = (3, 58)
# starting location = (3, 59)
# starting location = (3, 60)
# starting location = (3, 61)
# starting location = (3, 62)
# starting location = (3, 63)
# starting location = (3, 72)
# starting location = (3, 73)
# starting location = (3, 74)
# starting location = (3, 75)
# starting location = (3, 81)
# starting location = (3, 82)
# starting location = (3, 83)
# starting location = (3, 84)
# starting location = (3, 85)
# starting location = (3, 86)
# starting location = (3, 87)
# starting location = (3, 88)
# starting location = (3, 89)
# starting location = (3, 91)
# starting location = (3, 92)
# starting location = (3, 93)
# starting location = (3, 94)
# starting location = (3, 95)
# starting location = (3, 96)
# starting location = (3, 97)
# starting location = (3, 115)
# starting location = (3, 116)
# starting location = (3, 117)
# starting location = (3, 118)
# starting location = (3, 130)
# starting location = (3, 131)
# starting location = (3, 132)
# starting location = (3, 134)
# starting location = (3, 135)
# starting location = (4, 0)
# starting location = (4, 20)
# starting location = (4, 21)
# starting location = (4, 22)
# starting location = (4, 23)
# starting location = (4, 24)
# starting location = (4, 25)
# starting location = (4, 34)
# starting location = (4, 35)
# starting location = (4, 37)
# starting location = (4, 38)
# starting location = (4, 39)
# starting location = (4, 40)
# starting location = (4, 41)
# starting location = (4, 42)
# starting location = (4, 52)
# starting location = (4, 53)
# starting location = (4, 54)
# starting location = (4, 55)
# starting location = (4, 56)
# starting location = (4, 57)
# starting location = (4, 58)
# starting location = (4, 59)
# starting location = (4, 60)
# starting location = (4, 61)
# starting location = (4, 62)
# starting location = (4, 63)
# starting location = (4, 64)
# starting location = (4, 66)
# starting location = (4, 67)
# starting location = (4, 68)
# starting location = (4, 73)
# starting location = (4, 74)
# starting location = (4, 81)
# starting location = (4, 82)
# starting location = (4, 83)
# starting location = (4, 84)
# starting location = (4, 85)
# starting location = (4, 86)
# starting location = (4, 87)
# starting location = (4, 88)
# starting location = (4, 89)
# starting location = (4, 91)
# starting location = (4, 92)
# starting location = (4, 110)
# starting location = (4, 111)
# starting location = (4, 112)
# starting location = (4, 115)
# starting location = (4, 116)
# starting location = (4, 117)
# starting location = (4, 118)
# starting location = (4, 134)
# starting location = (4, 135)
# starting location = (5, 0)
# starting location = (5, 19)
# starting location = (5, 20)
# starting location = (5, 21)
# starting location = (5, 22)
# starting location = (5, 23)
# starting location = (5, 24)
# starting location = (5, 25)
# starting location = (5, 26)
# starting location = (5, 34)
# starting location = (5, 35)
# starting location = (5, 36)
# starting location = (5, 37)
# starting location = (5, 38)
# starting location = (5, 39)
# starting location = (5, 40)
# starting location = (5, 41)
# starting location = (5, 48)
# starting location = (5, 49)
# starting location = (5, 50)
# starting location = (5, 51)
# starting location = (5, 52)
# starting location = (5, 53)
# starting location = (5, 54)
# starting location = (5, 55)
# starting location = (5, 57)
# starting location = (5, 58)
# starting location = (5, 59)
# starting location = (5, 60)
# starting location = (5, 62)
# starting location = (5, 63)
# starting location = (5, 64)
# starting location = (5, 65)
# starting location = (5, 66)
# starting location = (5, 67)
# starting location = (5, 68)
# starting location = (5, 78)
# starting location = (5, 79)
# starting location = (5, 84)
# starting location = (5, 85)
# starting location = (5, 86)
# starting location = (5, 87)
# starting location = (5, 88)
# starting location = (5, 89)
# starting location = (5, 91)
# starting location = (5, 92)
# starting location = (5, 93)
# starting location = (5, 109)
# starting location = (5, 110)
# starting location = (5, 111)
# starting location = (5, 112)
# starting location = (5, 116)
# starting location = (5, 117)
# starting location = (5, 134)
# starting location = (5, 135)
# starting location = (6, 0)
# starting location = (6, 19)
# starting location = (6, 20)
# starting location = (6, 21)
# starting location = (6, 22)
# starting location = (6, 23)
# starting location = (6, 24)
# starting location = (6, 25)
# starting location = (6, 26)
# starting location = (6, 35)
# starting location = (6, 36)
# starting location = (6, 37)
# starting location = (6, 38)
# starting location = (6, 39)
# starting location = (6, 44)
# starting location = (6, 45)
# starting location = (6, 49)
# starting location = (6, 50)
# starting location = (6, 51)
# starting location = (6, 52)
# starting location = (6, 53)
# starting location = (6, 54)
# starting location = (6, 55)
# starting location = (6, 56)
# starting location = (6, 57)
# starting location = (6, 58)
# starting location = (6, 59)
# starting location = (6, 60)
# starting location = (6, 62)
# starting location = (6, 63)
# starting location = (6, 64)
# starting location = (6, 65)
# starting location = (6, 66)
# starting location = (6, 67)
# starting location = (6, 78)
# starting location = (6, 79)
# starting location = (6, 83)
# starting location = (6, 84)
# starting location = (6, 85)
# starting location = (6, 86)
# starting location = (6, 87)
# starting location = (6, 88)
# starting location = (6, 89)
# starting location = (6, 90)
# starting location = (6, 91)
# starting location = (6, 92)
# starting location = (6, 93)
# starting location = (6, 94)
# starting location = (6, 110)
# starting location = (7, 0)
# starting location = (7, 2)
# starting location = (7, 3)
# starting location = (7, 4)
# starting location = (7, 16)
# starting location = (7, 17)
# starting location = (7, 22)
# starting location = (7, 23)
# starting location = (7, 36)
# starting location = (7, 37)
# starting location = (7, 38)
# starting location = (7, 39)
# starting location = (7, 40)
# starting location = (7, 43)
# starting location = (7, 44)
# starting location = (7, 45)
# starting location = (7, 49)
# starting location = (7, 50)
# starting location = (7, 51)
# starting location = (7, 52)
# starting location = (7, 53)
# starting location = (7, 54)
# starting location = (7, 55)
# starting location = (7, 56)
# starting location = (7, 57)
# starting location = (7, 58)
# starting location = (7, 59)
# starting location = (7, 60)
# starting location = (7, 61)
# starting location = (7, 62)
# starting location = (7, 63)
# starting location = (7, 64)
# starting location = (7, 65)
# starting location = (7, 66)
# starting location = (7, 67)
# starting location = (7, 68)
# starting location = (7, 75)
# starting location = (7, 76)
# starting location = (7, 77)
# starting location = (7, 78)
# starting location = (7, 79)
# starting location = (7, 80)
# starting location = (7, 81)
# starting location = (7, 82)
# starting location = (7, 84)
# starting location = (7, 85)
# starting location = (7, 89)
# starting location = (7, 90)
# starting location = (7, 91)
# starting location = (7, 92)
# starting location = (7, 93)
# starting location = (7, 94)
# starting location = (7, 126)
# starting location = (7, 127)
# starting location = (7, 128)
# starting location = (8, 0)
# starting location = (8, 2)
# starting location = (8, 3)
# starting location = (8, 4)
# starting location = (8, 5)
# starting location = (8, 13)
# starting location = (8, 14)
# starting location = (8, 16)
# starting location = (8, 17)
# starting location = (8, 22)
# starting location = (8, 23)
# starting location = (8, 35)
# starting location = (8, 36)
# starting location = (8, 37)
# starting location = (8, 39)
# starting location = (8, 40)
# starting location = (8, 41)
# starting location = (8, 42)
# starting location = (8, 43)
# starting location = (8, 44)
# starting location = (8, 45)
# starting location = (8, 50)
# starting location = (8, 51)
# starting location = (8, 52)
# starting location = (8, 53)
# starting location = (8, 54)
# starting location = (8, 55)
# starting location = (8, 56)
# starting location = (8, 57)
# starting location = (8, 58)
# starting location = (8, 59)
# starting location = (8, 60)
# starting location = (8, 61)
# starting location = (8, 62)
# starting location = (8, 63)
# starting location = (8, 64)
# starting location = (8, 65)
# starting location = (8, 66)
# starting location = (8, 67)
# starting location = (8, 68)
# starting location = (8, 69)
# starting location = (8, 75)
# starting location = (8, 76)
# starting location = (8, 77)
# starting location = (8, 78)
# starting location = (8, 79)
# starting location = (8, 80)
# starting location = (8, 81)
# starting location = (8, 82)
# starting location = (8, 83)
# starting location = (8, 84)
# starting location = (8, 85)
# starting location = (8, 90)
# starting location = (8, 91)
# starting location = (8, 92)
# starting location = (8, 93)
# starting location = (8, 94)
# starting location = (8, 126)
# starting location = (8, 127)
# starting location = (8, 128)
# starting location = (8, 129)
# starting location = (8, 130)
# starting location = (8, 131)
# starting location = (9, 0)
# starting location = (9, 2)
# starting location = (9, 3)
# starting location = (9, 4)
# starting location = (9, 5)
# starting location = (9, 13)
# starting location = (9, 14)
# starting location = (9, 15)
# starting location = (9, 16)
# starting location = (9, 17)
# starting location = (9, 29)
# starting location = (9, 30)
# starting location = (9, 31)
# starting location = (9, 36)
# starting location = (9, 37)
# starting location = (9, 39)
# starting location = (9, 40)
# starting location = (9, 41)
# starting location = (9, 42)
# starting location = (9, 43)
# starting location = (9, 44)
# starting location = (9, 49)
# starting location = (9, 50)
# starting location = (9, 51)
# starting location = (9, 52)
# starting location = (9, 53)
# starting location = (9, 54)
# starting location = (9, 56)
# starting location = (9, 57)
# starting location = (9, 58)
# starting location = (9, 59)
# starting location = (9, 60)
# starting location = (9, 61)
# starting location = (9, 62)
# starting location = (9, 63)
# starting location = (9, 64)
# starting location = (9, 65)
# starting location = (9, 66)
# starting location = (9, 67)
# starting location = (9, 68)
# starting location = (9, 69)
# starting location = (9, 77)
# starting location = (9, 78)
# starting location = (9, 79)
# starting location = (9, 80)
# starting location = (9, 89)
# starting location = (9, 90)
# starting location = (9, 91)
# starting location = (9, 92)
# starting location = (9, 93)
# starting location = (9, 126)
# starting location = (9, 127)
# starting location = (9, 128)
# starting location = (9, 129)
# starting location = (9, 130)
# starting location = (9, 131)
# starting location = (10, 0)
# starting location = (10, 2)
# starting location = (10, 3)
# starting location = (10, 4)
# starting location = (10, 14)
# starting location = (10, 15)
# starting location = (10, 16)
# starting location = (10, 17)
# starting location = (10, 18)
# starting location = (10, 19)
# starting location = (10, 28)
# starting location = (10, 29)
# starting location = (10, 30)
# starting location = (10, 31)
# starting location = (10, 40)
# starting location = (10, 41)
# starting location = (10, 42)
# starting location = (10, 43)
# starting location = (10, 44)
# starting location = (10, 45)
# starting location = (10, 46)
# starting location = (10, 47)
# starting location = (10, 49)
# starting location = (10, 50)
# starting location = (10, 51)
# starting location = (10, 52)
# starting location = (10, 53)
# starting location = (10, 54)
# starting location = (10, 55)
# starting location = (10, 56)
# starting location = (10, 57)
# starting location = (10, 58)
# starting location = (10, 59)
# starting location = (10, 60)
# starting location = (10, 61)
# starting location = (10, 63)
# starting location = (10, 64)
# starting location = (10, 65)
# starting location = (10, 67)
# starting location = (10, 68)
# starting location = (10, 69)
# starting location = (10, 77)
# starting location = (10, 78)
# starting location = (10, 79)
# starting location = (10, 80)
# starting location = (10, 81)
# starting location = (10, 89)
# starting location = (10, 90)
# starting location = (10, 91)
# starting location = (10, 92)
# starting location = (10, 93)
# starting location = (10, 128)
# starting location = (10, 129)
# starting location = (10, 130)
# starting location = (11, 0)
# starting location = (11, 12)
# starting location = (11, 13)
# starting location = (11, 14)
# starting location = (11, 15)
# starting location = (11, 16)
# starting location = (11, 17)
# starting location = (11, 18)
# starting location = (11, 19)
# starting location = (11, 28)
# starting location = (11, 29)
# starting location = (11, 30)
# starting location = (11, 31)
# starting location = (11, 39)
# starting location = (11, 40)
# starting location = (11, 41)
# starting location = (11, 42)
# starting location = (11, 43)
# starting location = (11, 44)
# starting location = (11, 45)
# starting location = (11, 46)
# starting location = (11, 47)
# starting location = (11, 49)
# starting location = (11, 50)
# starting location = (11, 52)
# starting location = (11, 53)
# starting location = (11, 54)
# starting location = (11, 55)
# starting location = (11, 56)
# starting location = (11, 57)
# starting location = (11, 58)
# starting location = (11, 59)
# starting location = (11, 60)
# starting location = (11, 61)
# starting location = (11, 63)
# starting location = (11, 64)
# starting location = (11, 65)
# starting location = (11, 76)
# starting location = (11, 77)
# starting location = (11, 78)
# starting location = (11, 80)
# starting location = (11, 81)
# starting location = (11, 129)
# starting location = (11, 130)
# starting location = (12, 0)
# starting location = (12, 4)
# starting location = (12, 5)
# starting location = (12, 6)
# starting location = (12, 12)
# starting location = (12, 13)
# starting location = (12, 14)
# starting location = (12, 15)
# starting location = (12, 16)
# starting location = (12, 28)
# starting location = (12, 29)
# starting location = (12, 30)
# starting location = (12, 31)
# starting location = (12, 38)
# starting location = (12, 39)
# starting location = (12, 40)
# starting location = (12, 41)
# starting location = (12, 42)
# starting location = (12, 43)
# starting location = (12, 44)
# starting location = (12, 45)
# starting location = (12, 46)
# starting location = (12, 47)
# starting location = (12, 53)
# starting location = (12, 54)
# starting location = (12, 55)
# starting location = (12, 56)
# starting location = (12, 57)
# starting location = (12, 58)
# starting location = (12, 59)
# starting location = (12, 60)
# starting location = (12, 61)
# starting location = (12, 62)
# starting location = (12, 64)
# starting location = (12, 65)
# starting location = (12, 76)
# starting location = (12, 77)
# starting location = (12, 81)
# starting location = (12, 131)
# starting location = (13, 0)
# starting location = (13, 5)
# starting location = (13, 6)
# starting location = (13, 7)
# starting location = (13, 10)
# starting location = (13, 13)
# starting location = (13, 15)
# starting location = (13, 16)
# starting location = (13, 17)
# starting location = (13, 38)
# starting location = (13, 39)
# starting location = (13, 40)
# starting location = (13, 41)
# starting location = (13, 42)
# starting location = (13, 43)
# starting location = (13, 44)
# starting location = (13, 55)
# starting location = (13, 56)
# starting location = (13, 57)
# starting location = (13, 58)
# starting location = (13, 59)
# starting location = (13, 60)
# starting location = (13, 61)
# starting location = (13, 62)
# starting location = (13, 69)
# starting location = (13, 70)
# starting location = (13, 82)
# starting location = (13, 83)
# starting location = (13, 84)
# starting location = (13, 85)
# starting location = (13, 86)
# starting location = (14, 0)
# starting location = (14, 4)
# starting location = (14, 5)
# starting location = (14, 6)
# starting location = (14, 7)
# starting location = (14, 8)
# starting location = (14, 9)
# starting location = (14, 10)
# starting location = (14, 11)
# starting location = (14, 15)
# starting location = (14, 16)
# starting location = (14, 17)
# starting location = (14, 34)
# starting location = (14, 35)
# starting location = (14, 36)
# starting location = (14, 42)
# starting location = (14, 43)
# starting location = (14, 44)
# starting location = (14, 57)
# starting location = (14, 58)
# starting location = (14, 59)
# starting location = (14, 69)
# starting location = (14, 70)
# starting location = (14, 82)
# starting location = (14, 83)
# starting location = (14, 84)
# starting location = (14, 85)
# starting location = (14, 86)
# starting location = (15, 0)
# starting location = (15, 3)
# starting location = (15, 4)
# starting location = (15, 5)
# starting location = (15, 6)
# starting location = (15, 7)
# starting location = (15, 8)
# starting location = (15, 9)
# starting location = (15, 10)
# starting location = (15, 14)
# starting location = (15, 15)
# starting location = (15, 16)
# starting location = (15, 17)
# starting location = (15, 18)
# starting location = (15, 19)
# starting location = (15, 21)
# starting location = (15, 22)
# starting location = (15, 23)
# starting location = (15, 24)
# starting location = (15, 25)
# starting location = (15, 32)
# starting location = (15, 33)
# starting location = (15, 34)
# starting location = (15, 35)
# starting location = (15, 36)
# starting location = (15, 37)
# starting location = (15, 42)
# starting location = (15, 43)
# starting location = (15, 44)
# starting location = (15, 48)
# starting location = (15, 49)
# starting location = (15, 58)
# starting location = (15, 59)
# starting location = (15, 66)
# starting location = (15, 67)
# starting location = (15, 68)
# starting location = (15, 69)
# starting location = (15, 70)
# starting location = (15, 71)
# starting location = (15, 72)
# starting location = (15, 73)
# starting location = (15, 76)
# starting location = (15, 77)
# starting location = (15, 78)
# starting location = (15, 82)
# starting location = (15, 83)
# starting location = (15, 84)
# starting location = (15, 85)
# starting location = (15, 86)
# starting location = (15, 87)
# starting location = (16, 0)
# starting location = (16, 2)
# starting location = (16, 3)
# starting location = (16, 4)
# starting location = (16, 5)
# starting location = (16, 6)
# starting location = (16, 7)
# starting location = (16, 8)
# starting location = (16, 9)
# starting location = (16, 10)
# starting location = (16, 15)
# starting location = (16, 16)
# starting location = (16, 17)
# starting location = (16, 18)
# starting location = (16, 19)
# starting location = (16, 21)
# starting location = (16, 22)
# starting location = (16, 23)
# starting location = (16, 24)
# starting location = (16, 25)
# starting location = (16, 32)
# starting location = (16, 33)
# starting location = (16, 34)
# starting location = (16, 35)
# starting location = (16, 36)
# starting location = (16, 37)
# starting location = (16, 38)
# starting location = (16, 39)
# starting location = (16, 46)
# starting location = (16, 47)
# starting location = (16, 48)
# starting location = (16, 49)
# starting location = (16, 50)
# starting location = (16, 51)
# starting location = (16, 66)
# starting location = (16, 67)
# starting location = (16, 68)
# starting location = (16, 69)
# starting location = (16, 70)
# starting location = (16, 71)
# starting location = (16, 72)
# starting location = (16, 73)
# starting location = (16, 76)
# starting location = (16, 77)
# starting location = (16, 78)
# starting location = (16, 80)
# starting location = (16, 81)
# starting location = (16, 82)
# starting location = (16, 83)
# starting location = (16, 84)
# starting location = (16, 85)
# starting location = (16, 86)
# starting location = (16, 87)
# starting location = (17, 0)
# starting location = (17, 2)
# starting location = (17, 3)
# starting location = (17, 4)
# starting location = (17, 5)
# starting location = (17, 6)
# starting location = (17, 7)
# starting location = (17, 8)
# starting location = (17, 9)
# starting location = (17, 10)
# starting location = (17, 13)
# starting location = (17, 14)
# starting location = (17, 15)
# starting location = (17, 16)
# starting location = (17, 17)
# starting location = (17, 18)
# starting location = (17, 19)
# starting location = (17, 21)
# starting location = (17, 22)
# starting location = (17, 23)
# starting location = (17, 24)
# starting location = (17, 25)
# starting location = (17, 26)
# starting location = (17, 33)
# starting location = (17, 34)
# starting location = (17, 35)
# starting location = (17, 36)
# starting location = (17, 37)
# starting location = (17, 38)
# starting location = (17, 39)
# starting location = (17, 40)
# starting location = (17, 46)
# starting location = (17, 47)
# starting location = (17, 48)
# starting location = (17, 49)
# starting location = (17, 50)
# starting location = (17, 51)
# starting location = (17, 68)
# starting location = (17, 69)
# starting location = (17, 70)
# starting location = (17, 71)
# starting location = (17, 74)
# starting location = (17, 75)
# starting location = (17, 76)
# starting location = (17, 77)
# starting location = (17, 78)
# starting location = (17, 79)
# starting location = (17, 80)
# starting location = (17, 81)
# starting location = (17, 82)
# starting location = (17, 83)
# starting location = (17, 84)
# starting location = (17, 85)
# starting location = (17, 86)
# starting location = (17, 87)
# starting location = (17, 97)
# starting location = (17, 98)
# starting location = (18, 0)
# starting location = (18, 3)
# starting location = (18, 4)
# starting location = (18, 5)
# starting location = (18, 6)
# starting location = (18, 7)
# starting location = (18, 8)
# starting location = (18, 9)
# starting location = (18, 10)
# starting location = (18, 13)
# starting location = (18, 14)
# starting location = (18, 15)
# starting location = (18, 16)
# starting location = (18, 17)
# starting location = (18, 18)
# starting location = (18, 19)
# starting location = (18, 20)
# starting location = (18, 21)
# starting location = (18, 22)
# starting location = (18, 23)
# starting location = (18, 24)
# starting location = (18, 25)
# starting location = (18, 26)
# starting location = (18, 32)
# starting location = (18, 33)
# starting location = (18, 34)
# starting location = (18, 35)
# starting location = (18, 36)
# starting location = (18, 37)
# starting location = (18, 38)
# starting location = (18, 39)
# starting location = (18, 47)
# starting location = (18, 48)
# starting location = (18, 49)
# starting location = (18, 50)
# starting location = (18, 56)
# starting location = (18, 57)
# starting location = (18, 58)
# starting location = (18, 59)
# starting location = (18, 68)
# starting location = (18, 69)
# starting location = (18, 70)
# starting location = (18, 71)
# starting location = (18, 72)
# starting location = (18, 74)
# starting location = (18, 75)
# starting location = (18, 76)
# starting location = (18, 77)
# starting location = (18, 78)
# starting location = (18, 79)
# starting location = (18, 80)
# starting location = (18, 81)
# starting location = (18, 84)
# starting location = (18, 85)
# starting location = (18, 96)
# starting location = (18, 97)
# starting location = (18, 98)
# starting location = (19, 0)
# starting location = (19, 5)
# starting location = (19, 6)
# starting location = (19, 7)
# starting location = (19, 8)
# starting location = (19, 9)
# starting location = (19, 10)
# starting location = (19, 11)
# starting location = (19, 13)
# starting location = (19, 14)
# starting location = (19, 15)
# starting location = (19, 16)
# starting location = (19, 17)
# starting location = (19, 18)
# starting location = (19, 19)
# starting location = (19, 20)
# starting location = (19, 21)
# starting location = (19, 22)
# starting location = (19, 23)
# starting location = (19, 24)
# starting location = (19, 25)
# starting location = (19, 26)
# starting location = (19, 32)
# starting location = (19, 33)
# starting location = (19, 34)
# starting location = (19, 35)
# starting location = (19, 36)
# starting location = (19, 37)
# starting location = (19, 38)
# starting location = (19, 39)
# starting location = (19, 40)
# starting location = (19, 41)
# starting location = (19, 42)
# starting location = (19, 47)
# starting location = (19, 48)
# starting location = (19, 49)
# starting location = (19, 50)
# starting location = (19, 55)
# starting location = (19, 56)
# starting location = (19, 57)
# starting location = (19, 58)
# starting location = (19, 59)
# starting location = (19, 67)
# starting location = (19, 68)
# starting location = (19, 69)
# starting location = (19, 70)
# starting location = (19, 71)
# starting location = (19, 72)
# starting location = (19, 74)
# starting location = (19, 75)
# starting location = (19, 76)
# starting location = (19, 77)
# starting location = (19, 78)
# starting location = (19, 79)
# starting location = (19, 80)
# starting location = (19, 96)
# starting location = (19, 97)
# starting location = (19, 98)
# starting location = (20, 5)
# starting location = (20, 6)
# starting location = (20, 10)
# starting location = (20, 15)
# starting location = (20, 16)
# starting location = (20, 17)
# starting location = (20, 19)
# starting location = (20, 23)
# starting location = (20, 24)
# starting location = (20, 25)
# starting location = (20, 35)
# starting location = (20, 36)
# starting location = (20, 37)
# starting location = (20, 38)
# starting location = (20, 39)
# starting location = (20, 40)
# starting location = (20, 41)
# starting location = (20, 42)
# starting location = (20, 43)
# starting location = (20, 47)
# starting location = (20, 50)
# starting location = (20, 55)
# starting location = (20, 56)
# starting location = (20, 57)
# starting location = (20, 58)
# starting location = (20, 59)
# starting location = (20, 60)
# starting location = (20, 67)
# starting location = (20, 68)
# starting location = (20, 71)
# starting location = (20, 72)
# starting location = (20, 76)
# starting location = (20, 77)
# starting location = (20, 78)
# starting location = (20, 79)
# starting location = (20, 80)
# starting location = (20, 97)
# starting location = (20, 98)
# starting location = (21, 0)
# starting location = (21, 4)
# starting location = (21, 5)
# starting location = (21, 6)
# starting location = (21, 15)
# starting location = (21, 16)
# starting location = (21, 35)
# starting location = (21, 36)
# starting location = (21, 37)
# starting location = (21, 38)
# starting location = (21, 39)
# starting location = (21, 40)
# starting location = (21, 41)
# starting location = (21, 42)
# starting location = (21, 55)
# starting location = (21, 56)
# starting location = (21, 57)
# starting location = (21, 58)
# starting location = (21, 59)
# starting location = (21, 60)
# starting location = (21, 75)
# starting location = (21, 76)
# starting location = (21, 77)
# starting location = (21, 79)
# starting location = (21, 80)
# starting location = (21, 81)
# starting location = (21, 84)
# starting location = (21, 85)
# starting location = (22, 0)
# starting location = (22, 34)
# starting location = (22, 35)
# starting location = (22, 36)
# starting location = (22, 37)
# starting location = (22, 38)
# starting location = (22, 39)
# starting location = (22, 40)
# starting location = (22, 55)
# starting location = (22, 56)
# starting location = (22, 57)
# starting location = (22, 58)
# starting location = (22, 59)
# starting location = (22, 60)
# starting location = (22, 76)
# starting location = (22, 77)
# starting location = (22, 83)
# starting location = (22, 84)
# starting location = (22, 85)
# starting location = (22, 86)
# starting location = (22, 87)
# starting location = (22, 88)
# starting location = (22, 89)
# starting location = (23, 0)
# starting location = (23, 3)
# starting location = (23, 4)
# starting location = (23, 5)
# starting location = (23, 6)
# starting location = (23, 33)
# starting location = (23, 34)
# starting location = (23, 35)
# starting location = (23, 36)
# starting location = (23, 37)
# starting location = (23, 38)
# starting location = (23, 39)
# starting location = (23, 40)
# starting location = (23, 57)
# starting location = (23, 58)
# starting location = (23, 84)
# starting location = (23, 85)
# starting location = (23, 86)
# starting location = (23, 87)
# starting location = (23, 88)
# starting location = (24, 0)
# starting location = (24, 3)
# starting location = (24, 4)
# starting location = (24, 5)
# starting location = (24, 6)
# starting location = (24, 7)
# starting location = (24, 33)
# starting location = (24, 34)
# starting location = (24, 35)
# starting location = (24, 36)
# starting location = (24, 38)
# starting location = (24, 39)
# starting location = (24, 40)
# starting location = (24, 44)
# starting location = (24, 47)
# starting location = (24, 48)
# starting location = (24, 49)
# starting location = (24, 75)
# starting location = (24, 76)
# starting location = (24, 77)
# starting location = (24, 82)
# starting location = (24, 83)
# starting location = (24, 84)
# starting location = (24, 85)
# starting location = (24, 86)
# starting location = (24, 87)
# starting location = (24, 88)
# starting location = (25, 0)
# starting location = (25, 2)
# starting location = (25, 3)
# starting location = (25, 4)
# starting location = (25, 5)
# starting location = (25, 6)
# starting location = (25, 7)
# starting location = (25, 11)
# starting location = (25, 14)
# starting location = (25, 33)
# starting location = (25, 34)
# starting location = (25, 35)
# starting location = (25, 36)
# starting location = (25, 39)
# starting location = (25, 40)
# starting location = (25, 44)
# starting location = (25, 45)
# starting location = (25, 46)
# starting location = (25, 47)
# starting location = (25, 48)
# starting location = (25, 49)
# starting location = (25, 66)
# starting location = (25, 67)
# starting location = (25, 68)
# starting location = (25, 73)
# starting location = (25, 74)
# starting location = (25, 75)
# starting location = (25, 76)
# starting location = (25, 77)
# starting location = (25, 78)
# starting location = (25, 82)
# starting location = (25, 83)
# starting location = (25, 84)
# starting location = (25, 85)
# starting location = (25, 86)
# starting location = (25, 87)
# starting location = (25, 88)
# starting location = (25, 89)
# starting location = (26, 0)
# starting location = (26, 2)
# starting location = (26, 3)
# starting location = (26, 4)
# starting location = (26, 5)
# starting location = (26, 6)
# starting location = (26, 7)
# starting location = (26, 11)
# starting location = (26, 12)
# starting location = (26, 13)
# starting location = (26, 14)
# starting location = (26, 23)
# starting location = (26, 24)
# starting location = (26, 25)
# starting location = (26, 26)
# starting location = (26, 34)
# starting location = (26, 35)
# starting location = (26, 36)
# starting location = (26, 44)
# starting location = (26, 45)
# starting location = (26, 46)
# starting location = (26, 47)
# starting location = (26, 48)
# starting location = (26, 49)
# starting location = (26, 65)
# starting location = (26, 66)
# starting location = (26, 67)
# starting location = (26, 68)
# starting location = (26, 69)
# starting location = (26, 70)
# starting location = (26, 73)
# starting location = (26, 74)
# starting location = (26, 75)
# starting location = (26, 76)
# starting location = (26, 77)
# starting location = (26, 78)
# starting location = (26, 82)
# starting location = (26, 83)
# starting location = (26, 84)
# starting location = (26, 85)
# starting location = (26, 86)
# starting location = (26, 87)
# starting location = (26, 88)
# starting location = (26, 89)
# starting location = (26, 91)
# starting location = (26, 92)
# starting location = (26, 99)
# starting location = (26, 100)
# starting location = (27, 0)
# starting location = (27, 3)
# starting location = (27, 4)
# starting location = (27, 5)
# starting location = (27, 6)
# starting location = (27, 7)
# starting location = (27, 11)
# starting location = (27, 12)
# starting location = (27, 13)
# starting location = (27, 14)
# starting location = (27, 15)
# starting location = (27, 23)
# starting location = (27, 24)
# starting location = (27, 25)
# starting location = (27, 26)
# starting location = (27, 44)
# starting location = (27, 45)
# starting location = (27, 46)
# starting location = (27, 47)
# starting location = (27, 48)
# starting location = (27, 49)
# starting location = (27, 50)
# starting location = (27, 65)
# starting location = (27, 66)
# starting location = (27, 67)
# starting location = (27, 68)
# starting location = (27, 69)
# starting location = (27, 70)
# starting location = (27, 73)
# starting location = (27, 74)
# starting location = (27, 75)
# starting location = (27, 76)
# starting location = (27, 77)
# starting location = (27, 78)
# starting location = (27, 84)
# starting location = (27, 85)
# starting location = (27, 86)
# starting location = (27, 87)
# starting location = (27, 88)
# starting location = (27, 89)
# starting location = (27, 90)
# starting location = (27, 91)
# starting location = (27, 92)
# starting location = (27, 99)
# starting location = (27, 100)
# starting location = (27, 101)
# starting location = (27, 102)
# starting location = (27, 129)
# starting location = (28, 0)
# starting location = (28, 3)
# starting location = (28, 4)
# starting location = (28, 5)
# starting location = (28, 10)
# starting location = (28, 11)
# starting location = (28, 12)
# starting location = (28, 13)
# starting location = (28, 14)
# starting location = (28, 15)
# starting location = (28, 23)
# starting location = (28, 24)
# starting location = (28, 25)
# starting location = (28, 26)
# starting location = (28, 43)
# starting location = (28, 44)
# starting location = (28, 45)
# starting location = (28, 46)
# starting location = (28, 47)
# starting location = (28, 48)
# starting location = (28, 49)
# starting location = (28, 50)
# starting location = (28, 65)
# starting location = (28, 66)
# starting location = (28, 67)
# starting location = (28, 68)
# starting location = (28, 69)
# starting location = (28, 73)
# starting location = (28, 74)
# starting location = (28, 75)
# starting location = (28, 76)
# starting location = (28, 77)
# starting location = (28, 84)
# starting location = (28, 85)
# starting location = (28, 87)
# starting location = (28, 88)
# starting location = (28, 89)
# starting location = (28, 90)
# starting location = (28, 91)
# starting location = (28, 92)
# starting location = (28, 93)
# starting location = (28, 94)
# starting location = (28, 97)
# starting location = (28, 98)
# starting location = (28, 99)
# starting location = (28, 100)
# starting location = (28, 101)
# starting location = (28, 102)
# starting location = (28, 129)
# starting location = (29, 0)
# starting location = (29, 10)
# starting location = (29, 11)
# starting location = (29, 12)
# starting location = (29, 13)
# starting location = (29, 14)
# starting location = (29, 15)
# starting location = (29, 24)
# starting location = (29, 25)
# starting location = (29, 43)
# starting location = (29, 44)
# starting location = (29, 45)
# starting location = (29, 46)
# starting location = (29, 47)
# starting location = (29, 48)
# starting location = (29, 49)
# starting location = (29, 50)
# starting location = (29, 55)
# starting location = (29, 56)
# starting location = (29, 66)
# starting location = (29, 67)
# starting location = (29, 68)
# starting location = (29, 69)
# starting location = (29, 70)
# starting location = (29, 73)
# starting location = (29, 74)
# starting location = (29, 75)
# starting location = (29, 76)
# starting location = (29, 77)
# starting location = (29, 87)
# starting location = (29, 88)
# starting location = (29, 89)
# starting location = (29, 90)
# starting location = (29, 91)
# starting location = (29, 92)
# starting location = (29, 93)
# starting location = (29, 94)
# starting location = (29, 97)
# starting location = (29, 98)
# starting location = (29, 99)
# starting location = (29, 100)
# starting location = (29, 101)
# starting location = (29, 129)
# starting location = (29, 130)
# starting location = (29, 131)
# starting location = (30, 0)
# starting location = (30, 12)
# starting location = (30, 13)
# starting location = (30, 30)
# starting location = (30, 31)
# starting location = (30, 32)
# starting location = (30, 33)
# starting location = (30, 34)
# starting location = (30, 41)
# starting location = (30, 42)
# starting location = (30, 46)
# starting location = (30, 47)
# starting location = (30, 48)
# starting location = (30, 52)
# starting location = (30, 53)
# starting location = (30, 54)
# starting location = (30, 55)
# starting location = (30, 56)
# starting location = (30, 66)
# starting location = (30, 67)
# starting location = (30, 69)
# starting location = (30, 70)
# starting location = (30, 88)
# starting location = (30, 89)
# starting location = (30, 90)
# starting location = (30, 91)
# starting location = (30, 92)
# starting location = (30, 93)
# starting location = (30, 94)
# starting location = (30, 98)
# starting location = (30, 99)
# starting location = (30, 100)
# starting location = (30, 101)
# starting location = (30, 102)
# starting location = (30, 128)
# starting location = (30, 129)
# starting location = (30, 130)
# starting location = (30, 131)
# starting location = (31, 0)
# starting location = (31, 2)
# starting location = (31, 3)
# starting location = (31, 30)
# starting location = (31, 31)
# starting location = (31, 32)
# starting location = (31, 33)
# starting location = (31, 34)
# starting location = (31, 41)
# starting location = (31, 42)
# starting location = (31, 46)
# starting location = (31, 47)
# starting location = (31, 48)
# starting location = (31, 53)
# starting location = (31, 54)
# starting location = (31, 55)
# starting location = (31, 56)
# starting location = (31, 57)
# starting location = (31, 85)
# starting location = (31, 86)
# starting location = (31, 88)
# starting location = (31, 89)
# starting location = (31, 90)
# starting location = (31, 91)
# starting location = (31, 92)
# starting location = (31, 98)
# starting location = (31, 99)
# starting location = (31, 101)
# starting location = (31, 102)
# starting location = (31, 128)
# starting location = (31, 129)
# starting location = (31, 130)
# starting location = (31, 131)
# starting location = (32, 0)
# starting location = (32, 2)
# starting location = (32, 29)
# starting location = (32, 30)
# starting location = (32, 31)
# starting location = (32, 32)
# starting location = (32, 33)
# starting location = (32, 34)
# starting location = (32, 38)
# starting location = (32, 39)
# starting location = (32, 40)
# starting location = (32, 41)
# starting location = (32, 42)
# starting location = (32, 43)
# starting location = (32, 44)
# starting location = (32, 45)
# starting location = (32, 53)
# starting location = (32, 54)
# starting location = (32, 55)
# starting location = (32, 56)
# starting location = (32, 57)
# starting location = (32, 82)
# starting location = (32, 83)
# starting location = (32, 84)
# starting location = (32, 85)
# starting location = (32, 86)
# starting location = (32, 87)
# starting location = (32, 88)
# starting location = (32, 89)
# starting location = (32, 90)
# starting location = (32, 91)
# starting location = (32, 92)
# starting location = (32, 128)
# starting location = (32, 129)
# starting location = (33, 0)
# starting location = (33, 2)
# starting location = (33, 29)
# starting location = (33, 30)
# starting location = (33, 31)
# starting location = (33, 32)
# starting location = (33, 33)
# starting location = (33, 34)
# starting location = (33, 38)
# starting location = (33, 39)
# starting location = (33, 40)
# starting location = (33, 41)
# starting location = (33, 42)
# starting location = (33, 43)
# starting location = (33, 44)
# starting location = (33, 45)
# starting location = (33, 52)
# starting location = (33, 53)
# starting location = (33, 54)
# starting location = (33, 55)
# starting location = (33, 56)
# starting location = (33, 63)
# starting location = (33, 67)
# starting location = (33, 68)
# starting location = (33, 82)
# starting location = (33, 83)
# starting location = (33, 84)
# starting location = (33, 85)
# starting location = (33, 86)
# starting location = (33, 91)
# starting location = (33, 92)
# starting location = (33, 127)
# starting location = (33, 128)
# starting location = (33, 129)
# starting location = (34, 0)
# starting location = (34, 2)
# starting location = (34, 3)
# starting location = (34, 29)
# starting location = (34, 30)
# starting location = (34, 31)
# starting location = (34, 32)
# starting location = (34, 33)
# starting location = (34, 34)
# starting location = (34, 40)
# starting location = (34, 41)
# starting location = (34, 42)
# starting location = (34, 43)
# starting location = (34, 53)
# starting location = (34, 54)
# starting location = (34, 55)
# starting location = (34, 56)
# starting location = (34, 60)
# starting location = (34, 61)
# starting location = (34, 63)
# starting location = (34, 64)
# starting location = (34, 66)
# starting location = (34, 67)
# starting location = (34, 68)
# starting location = (34, 82)
# starting location = (34, 83)
# starting location = (34, 84)
# starting location = (34, 85)
# starting location = (34, 86)
# starting location = (34, 87)
# starting location = (34, 88)
# starting location = (34, 128)
# starting location = (34, 129)
# starting location = (35, 0)
# starting location = (35, 9)
# starting location = (35, 10)
# starting location = (35, 30)
# starting location = (35, 31)
# starting location = (35, 32)
# starting location = (35, 39)
# starting location = (35, 40)
# starting location = (35, 41)
# starting location = (35, 42)
# starting location = (35, 43)
# starting location = (35, 52)
# starting location = (35, 53)
# starting location = (35, 54)
# starting location = (35, 55)
# starting location = (35, 58)
# starting location = (35, 59)
# starting location = (35, 60)
# starting location = (35, 61)
# starting location = (35, 63)
# starting location = (35, 64)
# starting location = (35, 65)
# starting location = (35, 66)
# starting location = (35, 67)
# starting location = (35, 81)
# starting location = (35, 82)
# starting location = (35, 83)
# starting location = (35, 84)
# starting location = (35, 85)
# starting location = (35, 86)
# starting location = (35, 87)
# starting location = (35, 88)
# starting location = (35, 113)
# starting location = (35, 114)
# starting location = (35, 115)
# starting location = (35, 116)
# starting location = (36, 0)
# starting location = (36, 9)
# starting location = (36, 10)
# starting location = (36, 24)
# starting location = (36, 25)
# starting location = (36, 39)
# starting location = (36, 40)
# starting location = (36, 41)
# starting location = (36, 42)
# starting location = (36, 43)
# starting location = (36, 44)
# starting location = (36, 47)
# starting location = (36, 48)
# starting location = (36, 53)
# starting location = (36, 54)
# starting location = (36, 55)
# starting location = (36, 56)
# starting location = (36, 57)
# starting location = (36, 58)
# starting location = (36, 59)
# starting location = (36, 60)
# starting location = (36, 61)
# starting location = (36, 63)
# starting location = (36, 64)
# starting location = (36, 65)
# starting location = (36, 66)
# starting location = (36, 67)
# starting location = (36, 68)
# starting location = (36, 76)
# starting location = (36, 77)
# starting location = (36, 78)
# starting location = (36, 79)
# starting location = (36, 81)
# starting location = (36, 82)
# starting location = (36, 83)
# starting location = (36, 84)
# starting location = (36, 85)
# starting location = (36, 86)
# starting location = (36, 87)
# starting location = (36, 88)
# starting location = (36, 100)
# starting location = (36, 101)
# starting location = (36, 109)
# starting location = (36, 110)
# starting location = (36, 111)
# starting location = (36, 112)
# starting location = (36, 114)
# starting location = (36, 115)
# starting location = (36, 116)
# starting location = (36, 117)
# starting location = (37, 0)
# starting location = (37, 6)
# starting location = (37, 7)
# starting location = (37, 8)
# starting location = (37, 9)
# starting location = (37, 10)
# starting location = (37, 11)
# starting location = (37, 12)
# starting location = (37, 13)
# starting location = (37, 21)
# starting location = (37, 22)
# starting location = (37, 24)
# starting location = (37, 25)
# starting location = (37, 26)
# starting location = (37, 39)
# starting location = (37, 40)
# starting location = (37, 43)
# starting location = (37, 44)
# starting location = (37, 46)
# starting location = (37, 47)
# starting location = (37, 48)
# starting location = (37, 49)
# starting location = (37, 53)
# starting location = (37, 54)
# starting location = (37, 55)
# starting location = (37, 56)
# starting location = (37, 57)
# starting location = (37, 58)
# starting location = (37, 59)
# starting location = (37, 60)
# starting location = (37, 62)
# starting location = (37, 63)
# starting location = (37, 64)
# starting location = (37, 65)
# starting location = (37, 66)
# starting location = (37, 67)
# starting location = (37, 68)
# starting location = (37, 69)
# starting location = (37, 76)
# starting location = (37, 77)
# starting location = (37, 78)
# starting location = (37, 79)
# starting location = (37, 82)
# starting location = (37, 84)
# starting location = (37, 85)
# starting location = (37, 86)
# starting location = (37, 89)
# starting location = (37, 90)
# starting location = (37, 91)
# starting location = (37, 96)
# starting location = (37, 97)
# starting location = (37, 98)
# starting location = (37, 99)
# starting location = (37, 100)
# starting location = (37, 101)
# starting location = (37, 109)
# starting location = (37, 110)
# starting location = (37, 114)
# starting location = (37, 115)
# starting location = (37, 116)
# starting location = (37, 117)
# starting location = (37, 131)
# starting location = (37, 132)
# starting location = (37, 133)
# starting location = (37, 134)
# starting location = (37, 135)
# starting location = (38, 0)
# starting location = (38, 6)
# starting location = (38, 7)
# starting location = (38, 8)
# starting location = (38, 9)
# starting location = (38, 10)
# starting location = (38, 11)
# starting location = (38, 12)
# starting location = (38, 13)
# starting location = (38, 21)
# starting location = (38, 22)
# starting location = (38, 23)
# starting location = (38, 24)
# starting location = (38, 25)
# starting location = (38, 46)
# starting location = (38, 47)
# starting location = (38, 48)
# starting location = (38, 49)
# starting location = (38, 54)
# starting location = (38, 55)
# starting location = (38, 56)
# starting location = (38, 57)
# starting location = (38, 58)
# starting location = (38, 59)
# starting location = (38, 60)
# starting location = (38, 62)
# starting location = (38, 63)
# starting location = (38, 64)
# starting location = (38, 65)
# starting location = (38, 66)
# starting location = (38, 67)
# starting location = (38, 68)
# starting location = (38, 69)
# starting location = (38, 76)
# starting location = (38, 77)
# starting location = (38, 78)
# starting location = (38, 79)
# starting location = (38, 84)
# starting location = (38, 85)
# starting location = (38, 86)
# starting location = (38, 89)
# starting location = (38, 90)
# starting location = (38, 91)
# starting location = (38, 92)
# starting location = (38, 93)
# starting location = (38, 96)
# starting location = (38, 97)
# starting location = (38, 98)
# starting location = (38, 99)
# starting location = (38, 100)
# starting location = (38, 101)
# starting location = (38, 102)
# starting location = (38, 103)
# starting location = (38, 115)
# starting location = (38, 116)
# starting location = (38, 117)
# starting location = (38, 132)
# starting location = (38, 133)
# starting location = (38, 134)
# starting location = (38, 135)
# starting location = (39, 0)
# starting location = (39, 8)
# starting location = (39, 9)
# starting location = (39, 10)
# starting location = (39, 11)
# starting location = (39, 22)
# starting location = (39, 23)
# starting location = (39, 24)
# starting location = (39, 25)
# starting location = (39, 26)
# starting location = (39, 27)
# starting location = (39, 46)
# starting location = (39, 47)
# starting location = (39, 48)
# starting location = (39, 49)
# starting location = (39, 53)
# starting location = (39, 54)
# starting location = (39, 55)
# starting location = (39, 56)
# starting location = (39, 57)
# starting location = (39, 58)
# starting location = (39, 59)
# starting location = (39, 60)
# starting location = (39, 61)
# starting location = (39, 62)
# starting location = (39, 65)
# starting location = (39, 66)
# starting location = (39, 77)
# starting location = (39, 78)
# starting location = (39, 88)
# starting location = (39, 89)
# starting location = (39, 90)
# starting location = (39, 91)
# starting location = (39, 92)
# starting location = (39, 96)
# starting location = (39, 97)
# starting location = (39, 98)
# starting location = (39, 99)
# starting location = (39, 100)
# starting location = (39, 101)
# starting location = (39, 102)
# starting location = (39, 103)
# starting location = (39, 115)
# starting location = (39, 116)
# starting location = (39, 117)
# starting location = (39, 132)
# starting location = (39, 133)
# starting location = (39, 134)
# starting location = (39, 135)
# starting location = (40, 0)
# starting location = (40, 7)
# starting location = (40, 8)
# starting location = (40, 9)
# starting location = (40, 10)
# starting location = (40, 11)
# starting location = (40, 12)
# starting location = (40, 20)
# starting location = (40, 21)
# starting location = (40, 22)
# starting location = (40, 23)
# starting location = (40, 24)
# starting location = (40, 25)
# starting location = (40, 26)
# starting location = (40, 27)
# starting location = (40, 51)
# starting location = (40, 52)
# starting location = (40, 53)
# starting location = (40, 54)
# starting location = (40, 55)
# starting location = (40, 56)
# starting location = (40, 57)
# starting location = (40, 58)
# starting location = (40, 59)
# starting location = (40, 60)
# starting location = (40, 61)
# starting location = (40, 62)
# starting location = (40, 63)
# starting location = (40, 64)
# starting location = (40, 65)
# starting location = (40, 66)
# starting location = (40, 88)
# starting location = (40, 89)
# starting location = (40, 90)
# starting location = (40, 91)
# starting location = (40, 92)
# starting location = (40, 93)
# starting location = (40, 97)
# starting location = (40, 98)
# starting location = (40, 99)
# starting location = (40, 100)
# starting location = (40, 101)
# starting location = (40, 102)
# starting location = (40, 103)
# starting location = (40, 130)
# starting location = (40, 131)
# starting location = (40, 132)
# starting location = (40, 133)
# starting location = (40, 134)
# starting location = (40, 135)
# best possible distance = 454
